# %% [markdown]
# # Low-light image enhancement using MIRNet

# %% [markdown]
# ## Introduction
#
# With the goal of recovering high-quality image content from its degraded version, image
# restoration enjoys numerous applications, such as in
# photography, security, medical imaging, and remote sensing. In this example, we implement the
# **MIRNet** model for low-light image enhancement, a fully-convolutional architecture that
# learns an enriched set of
# features that combines contextual information from multiple scales, while
# simultaneously preserving the high-resolution spatial details.
#
# ### References:
#
# - [Learning Enriched Features for Real Image Restoration and Enhancement](https://arxiv.org/abs/2003.06792)
# - [The Retinex Theory of Color Vision](http://www.cnbc.cmu.edu/~tai/cp_papers/E.Land_Retinex_Theory_ScientifcAmerican.pdf)
# - [Two deterministic half-quadratic regularization algorithms for computed imaging](https://ieeexplore.ieee.org/document/413553)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Downloading LOLDataset
#
# The **LoL Dataset** has been created for low-light image enhancement.
# It provides 485 images for training and 15 for testing. Each image pair in the dataset
# consists of a low-light input image and its corresponding well-exposed reference image.

# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# %cd "/content/drive/MyDrive/EE610"

# %%
# #!gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# !unzip -q lol_dataset.zip

# %%
# !mkdir "checkpoint"

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# We use 300 image pairs from the LoL Dataset's training set for training,
# and we use the remaining 185 image pairs for validation.
# We generate random crops of size `128 x 128` from the image pairs to be
# used for both training and validation.

# %%
random.seed(10)

IMAGE_SIZE = 64
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 400


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    enhanced_w = low_w
    enhanced_h = low_h
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        enhanced_h : enhanced_h + IMAGE_SIZE, enhanced_w : enhanced_w + IMAGE_SIZE
    ]
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>
# Val Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## MIRNet Model
#
# Here are the main features of the MIRNet model:
#
# - A feature extraction model that computes a complementary set of features across multiple
# spatial scales, while maintaining the original high-resolution features to preserve
# precise spatial details.
# - A regularly repeated mechanism for information exchange, where the features across
# multi-resolution branches are progressively fused together for improved representation
# learning.
# - A new approach to fuse multi-scale features using a selective kernel network
# that dynamically combines variable receptive fields and faithfully preserves
# the original feature information at each spatial resolution.
# - A recursive residual design that progressively breaks down the input signal
# in order to simplify the overall learning process, and allows the construction
# of very deep networks.
#
#
# ![](https://raw.githubusercontent.com/soumik12345/MIRNet/master/assets/mirnet_architecture.png)

# %% [markdown]
# ### Selective Kernel Feature Fusion
#
# The Selective Kernel Feature Fusion or SKFF module performs dynamic adjustment of
# receptive fields via two operations: **Fuse** and **Select**. The Fuse operator generates
# global feature descriptors by combining the information from multi-resolution streams.
# The Select operator uses these descriptors to recalibrate the feature maps (of different
# streams) followed by their aggregation.
#
# **Fuse**: The SKFF receives inputs from three parallel convolution streams carrying
# different scales of information. We first combine these multi-scale features using an
# element-wise sum, on which we apply Global Average Pooling (GAP) across the spatial
# dimension. Next, we apply a channel- downscaling convolution layer to generate a compact
# feature representation which passes through three parallel channel-upscaling convolution
# layers (one for each resolution stream) and provides us with three feature descriptors.
#
# **Select**: This operator applies the softmax function to the feature descriptors to
# obtain the corresponding activations that are used to adaptively recalibrate multi-scale
# feature maps. The aggregated features are defined as the sum of product of the corresponding
# multi-scale feature and the feature descriptor.
#
# ![](https://i.imgur.com/7U6ixF6.png)

# %%
# def selective_kernel_feature_fusion(
#     multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
# ):
#     channels = list(multi_scale_feature_1.shape)[-1]
#     combined_feature = layers.Add()(
#         [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
#     )
#     gap = layers.GlobalAveragePooling2D()(combined_feature)
#     channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
#     compact_feature_representation = layers.Conv2D(
#         filters=channels // 8, kernel_size=(1, 1), activation="relu"
#     )(channel_wise_statistics)
#     feature_descriptor_1 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_descriptor_2 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_descriptor_3 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_1 = multi_scale_feature_1 * feature_descriptor_1
#     feature_2 = multi_scale_feature_2 * feature_descriptor_2
#     feature_3 = multi_scale_feature_3 * feature_descriptor_3
#     aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
#     return aggregated_feature

def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3, multi_scale_feature_4
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3, multi_scale_feature_4]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_4 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    feature_4 = multi_scale_feature_4 * feature_descriptor_4
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3, feature_4])
    return aggregated_feature

# %% [markdown]
# ### Dual Attention Unit
#
# The Dual Attention Unit or DAU is used to extract features in the convolutional streams.
# While the SKFF block fuses information across multi-resolution branches, we also need a
# mechanism to share information within a feature tensor, both along the spatial and the
# channel dimensions which is done by the DAU block. The DAU suppresses less useful
# features and only allows more informative ones to pass further. This feature
# recalibration is achieved by using **Channel Attention** and **Spatial Attention**
# mechanisms.
#
# The **Channel Attention** branch exploits the inter-channel relationships of the
# convolutional feature maps by applying squeeze and excitation operations. Given a feature
# map, the squeeze operation applies Global Average Pooling across spatial dimensions to
# encode global context, thus yielding a feature descriptor. The excitation operator passes
# this feature descriptor through two convolutional layers followed by the sigmoid gating
# and generates activations. Finally, the output of Channel Attention branch is obtained by
# rescaling the input feature map with the output activations.
#
# The **Spatial Attention** branch is designed to exploit the inter-spatial dependencies of
# convolutional features. The goal of Spatial Attention is to generate a spatial attention
# map and use it to recalibrate the incoming features. To generate the spatial attention
# map, the Spatial Attention branch first independently applies Global Average Pooling and
# Max Pooling operations on input features along the channel dimensions and concatenates
# the outputs to form a resultant feature map which is then passed through a convolution
# and sigmoid activation to obtain the spatial attention map. This spatial attention map is
# then used to rescale the input feature map.
#
# ![](https://i.imgur.com/Dl0IwQs.png)

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = layers.Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# ### Multi-Scale Residual Block
#
# The Multi-Scale Residual Block is capable of generating a spatially-precise output by
# maintaining high-resolution representations, while receiving rich contextual information
# from low-resolutions. The MRB consists of multiple (three in this paper)
# fully-convolutional streams connected in parallel. It allows information exchange across
# parallel streams in order to consolidate the high-resolution features with the help of
# low-resolution features, and vice versa. The MIRNet employs a recursive residual design
# (with skip connections) to ease the flow of information during the learning process. In
# order to maintain the residual nature of our architecture, residual resizing modules are
# used to perform downsampling and upsampling operations that are used in the Multi-scale
# Residual Block.
#
# ![](https://i.imgur.com/wzZKV57.png)

# %%
# Recursive Residual Modules


# def down_sampling_module(input_tensor):
#     channels = list(input_tensor.shape)[-1]
#     main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
#         input_tensor
#     )
#     main_branch = layers.Conv2D(
#         channels, kernel_size=(3, 3), padding="same", activation="relu"
#     )(main_branch)
#     main_branch = layers.MaxPooling2D()(main_branch)
#     main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
#     skip_branch = layers.MaxPooling2D()(input_tensor)
#     skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
#     return layers.Add()([skip_branch, main_branch])

def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu", kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001),
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1), kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1), kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# def up_sampling_module(input_tensor):
#     channels = list(input_tensor.shape)[-1]
#     main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
#         input_tensor
#     )
#     main_branch = layers.Conv2D(
#         channels, kernel_size=(3, 3), padding="same", activation="relu"
#     )(main_branch)
#     main_branch = layers.UpSampling2D()(main_branch)
#     main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
#     skip_branch = layers.UpSampling2D()(input_tensor)
#     skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
#     return layers.Add()([skip_branch, main_branch])

def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu", kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001)
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1), kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1), kernel_regularizer=keras.regularizers.l1_l2(l1=0.00001, l2=0.00001))(skip_branch)
    return layers.Add()([skip_branch, main_branch])

# # MRB Block
# def multi_scale_residual_block(input_tensor, channels):
#     # features
#     level1 = input_tensor
#     level2 = down_sampling_module(input_tensor)
#     level3 = down_sampling_module(level2)
#     # DAU
#     level1_dau = dual_attention_unit_block(level1)
#     level2_dau = dual_attention_unit_block(level2)
#     level3_dau = dual_attention_unit_block(level3)
#     # SKFF
#     level1_skff = selective_kernel_feature_fusion(
#         level1_dau,
#         up_sampling_module(level2_dau),
#         up_sampling_module(up_sampling_module(level3_dau)),
#     )
#     level2_skff = selective_kernel_feature_fusion(
#         down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
#     )
#     level3_skff = selective_kernel_feature_fusion(
#         down_sampling_module(down_sampling_module(level1_dau)),
#         down_sampling_module(level2_dau),
#         level3_dau,
#     )
#     # DAU 2
#     level1_dau_2 = dual_attention_unit_block(level1_skff)
#     level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
#     level3_dau_2 = up_sampling_module(
#         up_sampling_module(dual_attention_unit_block(level3_skff))
#     )
#     # SKFF 2
#     skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2)
#     conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
#     return layers.Add()([input_tensor, conv])

# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    level4 = down_sampling_module(level3)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    level4_dau = dual_attention_unit_block(level4)

    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
        up_sampling_module(up_sampling_module(up_sampling_module(level4_dau))),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau),
        level2_dau,
        up_sampling_module(level3_dau),
        up_sampling_module(up_sampling_module(level4_dau)),
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
        up_sampling_module(level4_dau),
    )
    level4_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(down_sampling_module(level1_dau))),
        down_sampling_module(down_sampling_module(level2_dau)),
        down_sampling_module(level3_dau),
        level4_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    level4_dau_2 = up_sampling_module(
        up_sampling_module(
            up_sampling_module(dual_attention_unit_block(level4_skff))
    )
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2, level4_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %% [markdown]
# ### MIRNet Model

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=32)

# %% [markdown]
# ## Training
#
# - We train MIRNet using **Charbonnier Loss** as the loss function and **Adam
# Optimizer** with a learning rate of `1e-4`.
# - We use **Peak Signal Noise Ratio** or PSNR as a metric which is an expression for the
# ratio between the maximum possible value (power) of a signal and the power of distorting
# noise that affects the quality of its representation.

# %%
num_epochs = 150
lr = 1e-4

def scheduler(epoch, lr):
  # time-based decay
  decay = 1e-4/50
  return lr * 1/(1 + decay*epoch)

def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=lr)

# callback = keras.callbacks.LearningRateScheduler(scheduler, 1)

# filepath="/content/drive/MyDrive/EE610/checkpoint/model-{epoch:02d}-{loss:.4f}.h5"

# callback2 = keras.callbacks.ModelCheckpoint(
#     filepath=filepath,
#     monitor='val_loss',
#     mode='min',
#     verbose=1,
#     save_best_only=True)

tb_callback = keras.callbacks.TensorBoard(log_dir="./logs/Regularised_MIRNET", histogram_freq=1)

model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

# history = model.fit(
#     train_dataset,
#     validation_data=val_dataset,
#     epochs=150,
#     callbacks=[callback2, callback],
#     )

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        ),
        tb_callback,
    ],
)
# Out:
# C:\Users\Vinit\anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/150
# 100/100 [==============================] - 170s 821ms/step - loss: 6.9290 - peak_signal_noise_ratio: 62.2671 - val_loss: 5.8608 - val_peak_signal_noise_ratio: 63.5652
# Epoch 2/150
# 100/100 [==============================] - 52s 517ms/step - loss: 4.9805 - peak_signal_noise_ratio: 64.3020 - val_loss: 4.1807 - val_peak_signal_noise_ratio: 63.8752
# Epoch 3/150
# 100/100 [==============================] - 54s 543ms/step - loss: 3.5451 - peak_signal_noise_ratio: 63.9154 - val_loss: 2.9739 - val_peak_signal_noise_ratio: 64.0583
# Epoch 4/150
# 100/100 [==============================] - 52s 522ms/step - loss: 2.5569 - peak_signal_noise_ratio: 64.3244 - val_loss: 2.1960 - val_peak_signal_noise_ratio: 64.8597
# Epoch 5/150
# 100/100 [==============================] - 52s 521ms/step - loss: 1.9504 - peak_signal_noise_ratio: 64.8539 - val_loss: 1.7549 - val_peak_signal_noise_ratio: 63.3329
# Epoch 6/150
# 100/100 [==============================] - 58s 580ms/step - loss: 1.5572 - peak_signal_noise_ratio: 65.1569 - val_loss: 1.4399 - val_peak_signal_noise_ratio: 63.5385
# Epoch 7/150
# 100/100 [==============================] - 58s 579ms/step - loss: 1.2846 - peak_signal_noise_ratio: 65.0368 - val_loss: 1.1576 - val_peak_signal_noise_ratio: 65.8063
# Epoch 8/150
# 100/100 [==============================] - 56s 563ms/step - loss: 1.0712 - peak_signal_noise_ratio: 65.0134 - val_loss: 1.0013 - val_peak_signal_noise_ratio: 64.0932
# Epoch 9/150
# 100/100 [==============================] - 57s 565ms/step - loss: 0.8857 - peak_signal_noise_ratio: 65.5867 - val_loss: 0.8388 - val_peak_signal_noise_ratio: 64.1467
# Epoch 10/150
# 100/100 [==============================] - 58s 582ms/step - loss: 0.7416 - peak_signal_noise_ratio: 65.8638 - val_loss: 0.7029 - val_peak_signal_noise_ratio: 64.7239
# Epoch 11/150
# 100/100 [==============================] - 58s 579ms/step - loss: 0.6274 - peak_signal_noise_ratio: 65.7282 - val_loss: 0.5945 - val_peak_signal_noise_ratio: 64.9827
# Epoch 12/150
# 100/100 [==============================] - 59s 589ms/step - loss: 0.5265 - peak_signal_noise_ratio: 65.9918 - val_loss: 0.5215 - val_peak_signal_noise_ratio: 64.3917
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 13/150
# 100/100 [==============================] - 57s 573ms/step - loss: 0.4655 - peak_signal_noise_ratio: 66.2197 - val_loss: 0.4698 - val_peak_signal_noise_ratio: 65.4832
# Epoch 14/150
# 100/100 [==============================] - 55s 547ms/step - loss: 0.4362 - peak_signal_noise_ratio: 66.3292 - val_loss: 0.4454 - val_peak_signal_noise_ratio: 65.1840
# Epoch 15/150
# 100/100 [==============================] - 51s 513ms/step - loss: 0.4137 - peak_signal_noise_ratio: 66.2098 - val_loss: 0.4194 - val_peak_signal_noise_ratio: 65.5710
# Epoch 16/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.3851 - peak_signal_noise_ratio: 66.6342 - val_loss: 0.4073 - val_peak_signal_noise_ratio: 65.3253
# Epoch 17/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.3762 - peak_signal_noise_ratio: 66.2343 - val_loss: 0.3890 - val_peak_signal_noise_ratio: 65.1409
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 18/150
# 100/100 [==============================] - 55s 548ms/step - loss: 0.3563 - peak_signal_noise_ratio: 66.6950 - val_loss: 0.3714 - val_peak_signal_noise_ratio: 65.5594
# Epoch 19/150
# 100/100 [==============================] - 55s 554ms/step - loss: 0.3517 - peak_signal_noise_ratio: 66.3833 - val_loss: 0.3563 - val_peak_signal_noise_ratio: 65.9904
# Epoch 20/150
# 100/100 [==============================] - 57s 570ms/step - loss: 0.3443 - peak_signal_noise_ratio: 66.5562 - val_loss: 0.3553 - val_peak_signal_noise_ratio: 65.5172
# Epoch 21/150
# 100/100 [==============================] - 57s 568ms/step - loss: 0.3330 - peak_signal_noise_ratio: 66.6038 - val_loss: 0.3430 - val_peak_signal_noise_ratio: 65.9182
# Epoch 22/150
# 100/100 [==============================] - 57s 570ms/step - loss: 0.3260 - peak_signal_noise_ratio: 66.5603 - val_loss: 0.3325 - val_peak_signal_noise_ratio: 66.1673
# Epoch 23/150
# 100/100 [==============================] - 56s 563ms/step - loss: 0.3158 - peak_signal_noise_ratio: 66.7943 - val_loss: 0.3325 - val_peak_signal_noise_ratio: 65.8343
# Epoch 24/150
# 100/100 [==============================] - 57s 569ms/step - loss: 0.3110 - peak_signal_noise_ratio: 66.9214 - val_loss: 0.3259 - val_peak_signal_noise_ratio: 65.9975
# Epoch 25/150
# 100/100 [==============================] - 53s 534ms/step - loss: 0.3046 - peak_signal_noise_ratio: 66.7223 - val_loss: 0.3199 - val_peak_signal_noise_ratio: 65.6450
# Epoch 26/150
# 100/100 [==============================] - 55s 552ms/step - loss: 0.3014 - peak_signal_noise_ratio: 66.7621 - val_loss: 0.3173 - val_peak_signal_noise_ratio: 65.7249
# Epoch 27/150
# 100/100 [==============================] - 56s 557ms/step - loss: 0.2898 - peak_signal_noise_ratio: 67.0586 - val_loss: 0.3087 - val_peak_signal_noise_ratio: 65.9222
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 28/150
# 100/100 [==============================] - 57s 574ms/step - loss: 0.2889 - peak_signal_noise_ratio: 66.9747 - val_loss: 0.3022 - val_peak_signal_noise_ratio: 66.0200
# Epoch 29/150
# 100/100 [==============================] - 57s 567ms/step - loss: 0.2834 - peak_signal_noise_ratio: 67.0717 - val_loss: 0.2971 - val_peak_signal_noise_ratio: 66.1148
# Epoch 30/150
# 100/100 [==============================] - 54s 541ms/step - loss: 0.2833 - peak_signal_noise_ratio: 66.9836 - val_loss: 0.2924 - val_peak_signal_noise_ratio: 66.4379
# Epoch 31/150
# 100/100 [==============================] - 51s 510ms/step - loss: 0.2766 - peak_signal_noise_ratio: 67.0320 - val_loss: 0.2907 - val_peak_signal_noise_ratio: 66.0459
# Epoch 32/150
# 100/100 [==============================] - 52s 517ms/step - loss: 0.2764 - peak_signal_noise_ratio: 66.9459 - val_loss: 0.3003 - val_peak_signal_noise_ratio: 65.6281
# Epoch 33/150
# 100/100 [==============================] - 53s 529ms/step - loss: 0.2693 - peak_signal_noise_ratio: 67.2570 - val_loss: 0.2874 - val_peak_signal_noise_ratio: 66.2188
# Epoch 34/150
# 100/100 [==============================] - 52s 515ms/step - loss: 0.2688 - peak_signal_noise_ratio: 67.2879 - val_loss: 0.2852 - val_peak_signal_noise_ratio: 65.9794
# Epoch 35/150
# 100/100 [==============================] - 53s 534ms/step - loss: 0.2719 - peak_signal_noise_ratio: 66.8178 - val_loss: 0.2691 - val_peak_signal_noise_ratio: 66.9638
# Epoch 36/150
# 100/100 [==============================] - 52s 523ms/step - loss: 0.2688 - peak_signal_noise_ratio: 66.9312 - val_loss: 0.2790 - val_peak_signal_noise_ratio: 66.3022
# Epoch 37/150
# 100/100 [==============================] - 51s 513ms/step - loss: 0.2657 - peak_signal_noise_ratio: 66.8295 - val_loss: 0.2831 - val_peak_signal_noise_ratio: 65.9930
# Epoch 38/150
# 100/100 [==============================] - 50s 498ms/step - loss: 0.2580 - peak_signal_noise_ratio: 67.4259 - val_loss: 0.2833 - val_peak_signal_noise_ratio: 65.6057
# Epoch 39/150
# 100/100 [==============================] - 53s 526ms/step - loss: 0.2590 - peak_signal_noise_ratio: 67.1419 - val_loss: 0.2749 - val_peak_signal_noise_ratio: 66.1502
# Epoch 40/150
# 100/100 [==============================] - 54s 537ms/step - loss: 0.2565 - peak_signal_noise_ratio: 67.1558 - val_loss: 0.2619 - val_peak_signal_noise_ratio: 66.9663
# Epoch 41/150
# 100/100 [==============================] - 54s 534ms/step - loss: 0.2607 - peak_signal_noise_ratio: 66.7376 - val_loss: 0.2652 - val_peak_signal_noise_ratio: 66.2378
# Epoch 42/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.2535 - peak_signal_noise_ratio: 67.1245 - val_loss: 0.2657 - val_peak_signal_noise_ratio: 66.4879
# Epoch 43/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.2500 - peak_signal_noise_ratio: 67.2403 - val_loss: 0.2664 - val_peak_signal_noise_ratio: 66.2615
# Epoch 44/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2517 - peak_signal_noise_ratio: 67.1277 - val_loss: 0.2578 - val_peak_signal_noise_ratio: 66.6957
# Epoch 45/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2479 - peak_signal_noise_ratio: 67.1651 - val_loss: 0.2675 - val_peak_signal_noise_ratio: 65.5393
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 46/150
# 100/100 [==============================] - 53s 526ms/step - loss: 0.2482 - peak_signal_noise_ratio: 67.0994 - val_loss: 0.2634 - val_peak_signal_noise_ratio: 66.2188
# Epoch 47/150
# 100/100 [==============================] - 54s 541ms/step - loss: 0.2469 - peak_signal_noise_ratio: 67.1320 - val_loss: 0.2668 - val_peak_signal_noise_ratio: 65.7967
# Epoch 48/150
# 100/100 [==============================] - 55s 553ms/step - loss: 0.2475 - peak_signal_noise_ratio: 67.0425 - val_loss: 0.2541 - val_peak_signal_noise_ratio: 66.4566
# Epoch 49/150
# 100/100 [==============================] - 54s 545ms/step - loss: 0.2445 - peak_signal_noise_ratio: 67.1522 - val_loss: 0.2554 - val_peak_signal_noise_ratio: 66.4309
# Epoch 50/150
# 100/100 [==============================] - 56s 557ms/step - loss: 0.2394 - peak_signal_noise_ratio: 67.4183 - val_loss: 0.2602 - val_peak_signal_noise_ratio: 66.4326
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 51/150
# 100/100 [==============================] - 53s 526ms/step - loss: 0.2396 - peak_signal_noise_ratio: 67.4471 - val_loss: 0.2612 - val_peak_signal_noise_ratio: 65.9765
# Epoch 52/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2413 - peak_signal_noise_ratio: 67.2648 - val_loss: 0.2566 - val_peak_signal_noise_ratio: 66.3546
# Epoch 53/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2360 - peak_signal_noise_ratio: 67.5258 - val_loss: 0.2613 - val_peak_signal_noise_ratio: 65.9645
# Epoch 54/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2386 - peak_signal_noise_ratio: 67.3633 - val_loss: 0.2498 - val_peak_signal_noise_ratio: 66.5869
# Epoch 55/150
# 100/100 [==============================] - 51s 510ms/step - loss: 0.2369 - peak_signal_noise_ratio: 67.5312 - val_loss: 0.2482 - val_peak_signal_noise_ratio: 66.7772
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 56/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.2392 - peak_signal_noise_ratio: 67.3465 - val_loss: 0.2609 - val_peak_signal_noise_ratio: 66.0230
# Epoch 57/150
# 100/100 [==============================] - 51s 514ms/step - loss: 0.2378 - peak_signal_noise_ratio: 67.2997 - val_loss: 0.2547 - val_peak_signal_noise_ratio: 66.3245
# Epoch 58/150
# 100/100 [==============================] - 51s 513ms/step - loss: 0.2337 - peak_signal_noise_ratio: 67.4487 - val_loss: 0.2558 - val_peak_signal_noise_ratio: 66.0782
# Epoch 59/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2324 - peak_signal_noise_ratio: 67.6938 - val_loss: 0.2598 - val_peak_signal_noise_ratio: 65.9885
# Epoch 60/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.2350 - peak_signal_noise_ratio: 67.4155 - val_loss: 0.2470 - val_peak_signal_noise_ratio: 66.7078
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 61/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2353 - peak_signal_noise_ratio: 67.4406 - val_loss: 0.2567 - val_peak_signal_noise_ratio: 66.0647
# Epoch 62/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2368 - peak_signal_noise_ratio: 67.4050 - val_loss: 0.2624 - val_peak_signal_noise_ratio: 65.7918
# Epoch 63/150
# 100/100 [==============================] - 50s 504ms/step - loss: 0.2352 - peak_signal_noise_ratio: 67.3499 - val_loss: 0.2623 - val_peak_signal_noise_ratio: 65.7542
# Epoch 64/150
# 100/100 [==============================] - 50s 502ms/step - loss: 0.2351 - peak_signal_noise_ratio: 67.4684 - val_loss: 0.2586 - val_peak_signal_noise_ratio: 66.0081
# Epoch 65/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2391 - peak_signal_noise_ratio: 67.2359 - val_loss: 0.2552 - val_peak_signal_noise_ratio: 66.0549
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 66/150
# 100/100 [==============================] - 51s 510ms/step - loss: 0.2384 - peak_signal_noise_ratio: 67.2844 - val_loss: 0.2558 - val_peak_signal_noise_ratio: 66.1965
# Epoch 67/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2375 - peak_signal_noise_ratio: 67.3096 - val_loss: 0.2582 - val_peak_signal_noise_ratio: 65.9302
# Epoch 68/150
# 100/100 [==============================] - 50s 503ms/step - loss: 0.2307 - peak_signal_noise_ratio: 67.6458 - val_loss: 0.2585 - val_peak_signal_noise_ratio: 65.9341
# Epoch 69/150
# 100/100 [==============================] - 50s 498ms/step - loss: 0.2364 - peak_signal_noise_ratio: 67.3187 - val_loss: 0.2564 - val_peak_signal_noise_ratio: 66.1801
# Epoch 70/150
# 100/100 [==============================] - 50s 501ms/step - loss: 0.2347 - peak_signal_noise_ratio: 67.3995 - val_loss: 0.2511 - val_peak_signal_noise_ratio: 66.5119
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 71/150
# 100/100 [==============================] - 51s 505ms/step - loss: 0.2375 - peak_signal_noise_ratio: 67.3367 - val_loss: 0.2603 - val_peak_signal_noise_ratio: 66.0352
# Epoch 72/150
# 100/100 [==============================] - 51s 512ms/step - loss: 0.2386 - peak_signal_noise_ratio: 67.1158 - val_loss: 0.2587 - val_peak_signal_noise_ratio: 66.3153
# Epoch 73/150
# 100/100 [==============================] - 52s 516ms/step - loss: 0.2360 - peak_signal_noise_ratio: 67.4241 - val_loss: 0.2604 - val_peak_signal_noise_ratio: 65.8539
# Epoch 74/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.2336 - peak_signal_noise_ratio: 67.5884 - val_loss: 0.2591 - val_peak_signal_noise_ratio: 65.9390
# Epoch 75/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2349 - peak_signal_noise_ratio: 67.4235 - val_loss: 0.2530 - val_peak_signal_noise_ratio: 66.1893
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 76/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2353 - peak_signal_noise_ratio: 67.3235 - val_loss: 0.2587 - val_peak_signal_noise_ratio: 65.7506
# Epoch 77/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2352 - peak_signal_noise_ratio: 67.4486 - val_loss: 0.2569 - val_peak_signal_noise_ratio: 66.0146
# Epoch 78/150
# 100/100 [==============================] - 50s 501ms/step - loss: 0.2381 - peak_signal_noise_ratio: 67.2127 - val_loss: 0.2548 - val_peak_signal_noise_ratio: 66.3450
# Epoch 79/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2344 - peak_signal_noise_ratio: 67.3822 - val_loss: 0.2646 - val_peak_signal_noise_ratio: 65.6547
# Epoch 80/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2334 - peak_signal_noise_ratio: 67.5648 - val_loss: 0.2545 - val_peak_signal_noise_ratio: 66.2301
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 81/150
# 100/100 [==============================] - 52s 521ms/step - loss: 0.2326 - peak_signal_noise_ratio: 67.4749 - val_loss: 0.2542 - val_peak_signal_noise_ratio: 66.4217
# Epoch 82/150
# 100/100 [==============================] - 50s 498ms/step - loss: 0.2333 - peak_signal_noise_ratio: 67.5471 - val_loss: 0.2588 - val_peak_signal_noise_ratio: 66.1326
# Epoch 83/150
# 100/100 [==============================] - 52s 519ms/step - loss: 0.2349 - peak_signal_noise_ratio: 67.4709 - val_loss: 0.2535 - val_peak_signal_noise_ratio: 66.2302
# Epoch 84/150
# 100/100 [==============================] - 57s 570ms/step - loss: 0.2365 - peak_signal_noise_ratio: 67.2464 - val_loss: 0.2502 - val_peak_signal_noise_ratio: 66.3079
# Epoch 85/150
# 100/100 [==============================] - 51s 514ms/step - loss: 0.2350 - peak_signal_noise_ratio: 67.4442 - val_loss: 0.2567 - val_peak_signal_noise_ratio: 66.0611
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 86/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2326 - peak_signal_noise_ratio: 67.6653 - val_loss: 0.2610 - val_peak_signal_noise_ratio: 65.7136
# Epoch 87/150
# 100/100 [==============================] - 51s 513ms/step - loss: 0.2354 - peak_signal_noise_ratio: 67.3577 - val_loss: 0.2539 - val_peak_signal_noise_ratio: 66.0088
# Epoch 88/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.2360 - peak_signal_noise_ratio: 67.2835 - val_loss: 0.2585 - val_peak_signal_noise_ratio: 65.9772
# Epoch 89/150
# 100/100 [==============================] - 54s 540ms/step - loss: 0.2339 - peak_signal_noise_ratio: 67.5483 - val_loss: 0.2527 - val_peak_signal_noise_ratio: 66.5552
# Epoch 90/150
# 100/100 [==============================] - 53s 527ms/step - loss: 0.2357 - peak_signal_noise_ratio: 67.3903 - val_loss: 0.2609 - val_peak_signal_noise_ratio: 65.8438
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 91/150
# 100/100 [==============================] - 51s 514ms/step - loss: 0.2314 - peak_signal_noise_ratio: 67.6130 - val_loss: 0.2586 - val_peak_signal_noise_ratio: 65.8674
# Epoch 92/150
# 100/100 [==============================] - 53s 531ms/step - loss: 0.2337 - peak_signal_noise_ratio: 67.4830 - val_loss: 0.2591 - val_peak_signal_noise_ratio: 66.1207
# Epoch 93/150
# 100/100 [==============================] - 52s 518ms/step - loss: 0.2370 - peak_signal_noise_ratio: 67.3718 - val_loss: 0.2526 - val_peak_signal_noise_ratio: 66.6907
# Epoch 94/150
# 100/100 [==============================] - 53s 530ms/step - loss: 0.2363 - peak_signal_noise_ratio: 67.4130 - val_loss: 0.2616 - val_peak_signal_noise_ratio: 65.9804
# Epoch 95/150
# 100/100 [==============================] - 51s 515ms/step - loss: 0.2334 - peak_signal_noise_ratio: 67.6105 - val_loss: 0.2628 - val_peak_signal_noise_ratio: 65.5541
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 96/150
# 100/100 [==============================] - 52s 518ms/step - loss: 0.2368 - peak_signal_noise_ratio: 67.2687 - val_loss: 0.2564 - val_peak_signal_noise_ratio: 65.7877
# Epoch 97/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.2321 - peak_signal_noise_ratio: 67.5796 - val_loss: 0.2591 - val_peak_signal_noise_ratio: 65.9598
# Epoch 98/150
# 100/100 [==============================] - 52s 523ms/step - loss: 0.2358 - peak_signal_noise_ratio: 67.4341 - val_loss: 0.2530 - val_peak_signal_noise_ratio: 66.1993
# Epoch 99/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2327 - peak_signal_noise_ratio: 67.5520 - val_loss: 0.2582 - val_peak_signal_noise_ratio: 66.1074
# Epoch 100/150
# 100/100 [==============================] - 51s 513ms/step - loss: 0.2342 - peak_signal_noise_ratio: 67.4770 - val_loss: 0.2552 - val_peak_signal_noise_ratio: 65.9628
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 101/150
# 100/100 [==============================] - 50s 499ms/step - loss: 0.2338 - peak_signal_noise_ratio: 67.5165 - val_loss: 0.2527 - val_peak_signal_noise_ratio: 66.2445
# Epoch 102/150
# 100/100 [==============================] - 50s 497ms/step - loss: 0.2407 - peak_signal_noise_ratio: 66.9881 - val_loss: 0.2575 - val_peak_signal_noise_ratio: 65.9807
# Epoch 103/150
# 100/100 [==============================] - 50s 500ms/step - loss: 0.2373 - peak_signal_noise_ratio: 67.2947 - val_loss: 0.2542 - val_peak_signal_noise_ratio: 66.4735
# Epoch 104/150
# 100/100 [==============================] - 53s 528ms/step - loss: 0.2319 - peak_signal_noise_ratio: 67.6649 - val_loss: 0.2531 - val_peak_signal_noise_ratio: 66.3297
# Epoch 105/150
# 100/100 [==============================] - 52s 522ms/step - loss: 0.2378 - peak_signal_noise_ratio: 67.2557 - val_loss: 0.2572 - val_peak_signal_noise_ratio: 66.0246
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 106/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2360 - peak_signal_noise_ratio: 67.2858 - val_loss: 0.2568 - val_peak_signal_noise_ratio: 66.1522
# Epoch 107/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2357 - peak_signal_noise_ratio: 67.3939 - val_loss: 0.2588 - val_peak_signal_noise_ratio: 65.8220
# Epoch 108/150
# 100/100 [==============================] - 51s 508ms/step - loss: 0.2343 - peak_signal_noise_ratio: 67.3578 - val_loss: 0.2551 - val_peak_signal_noise_ratio: 66.0762
# Epoch 109/150
# 100/100 [==============================] - 50s 504ms/step - loss: 0.2343 - peak_signal_noise_ratio: 67.3743 - val_loss: 0.2548 - val_peak_signal_noise_ratio: 65.7319
# Epoch 110/150
# 100/100 [==============================] - 52s 518ms/step - loss: 0.2351 - peak_signal_noise_ratio: 67.5354 - val_loss: 0.2519 - val_peak_signal_noise_ratio: 66.3299
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 111/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2352 - peak_signal_noise_ratio: 67.4900 - val_loss: 0.2582 - val_peak_signal_noise_ratio: 66.1393
# Epoch 112/150
# 100/100 [==============================] - 52s 517ms/step - loss: 0.2337 - peak_signal_noise_ratio: 67.4549 - val_loss: 0.2563 - val_peak_signal_noise_ratio: 66.0780
# Epoch 113/150
# 100/100 [==============================] - 52s 516ms/step - loss: 0.2348 - peak_signal_noise_ratio: 67.4786 - val_loss: 0.2541 - val_peak_signal_noise_ratio: 66.3400
# Epoch 114/150
# 100/100 [==============================] - 51s 515ms/step - loss: 0.2373 - peak_signal_noise_ratio: 67.2409 - val_loss: 0.2514 - val_peak_signal_noise_ratio: 66.5657
# Epoch 115/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2334 - peak_signal_noise_ratio: 67.4814 - val_loss: 0.2607 - val_peak_signal_noise_ratio: 65.7671
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# Epoch 116/150
# 100/100 [==============================] - 51s 510ms/step - loss: 0.2350 - peak_signal_noise_ratio: 67.3510 - val_loss: 0.2486 - val_peak_signal_noise_ratio: 66.3821
# Epoch 117/150
# 100/100 [==============================] - 51s 505ms/step - loss: 0.2354 - peak_signal_noise_ratio: 67.3647 - val_loss: 0.2534 - val_peak_signal_noise_ratio: 66.1100
# Epoch 118/150
# 100/100 [==============================] - 52s 516ms/step - loss: 0.2369 - peak_signal_noise_ratio: 67.2662 - val_loss: 0.2573 - val_peak_signal_noise_ratio: 65.7754
# Epoch 119/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.2345 - peak_signal_noise_ratio: 67.3192 - val_loss: 0.2505 - val_peak_signal_noise_ratio: 66.4781
# Epoch 120/150
# 100/100 [==============================] - 52s 518ms/step - loss: 0.2334 - peak_signal_noise_ratio: 67.5443 - val_loss: 0.2606 - val_peak_signal_noise_ratio: 65.7184
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 1.9073485846288207e-10.
# Epoch 121/150
# 100/100 [==============================] - 52s 520ms/step - loss: 0.2348 - peak_signal_noise_ratio: 67.4304 - val_loss: 0.2558 - val_peak_signal_noise_ratio: 66.2684
# Epoch 122/150
# 100/100 [==============================] - 51s 507ms/step - loss: 0.2330 - peak_signal_noise_ratio: 67.4961 - val_loss: 0.2553 - val_peak_signal_noise_ratio: 66.1225
# Epoch 123/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2345 - peak_signal_noise_ratio: 67.5022 - val_loss: 0.2592 - val_peak_signal_noise_ratio: 66.3623
# Epoch 124/150
# 100/100 [==============================] - 51s 506ms/step - loss: 0.2397 - peak_signal_noise_ratio: 67.0432 - val_loss: 0.2620 - val_peak_signal_noise_ratio: 66.0842
# Epoch 125/150
# 100/100 [==============================] - 53s 531ms/step - loss: 0.2314 - peak_signal_noise_ratio: 67.6991 - val_loss: 0.2511 - val_peak_signal_noise_ratio: 66.4131
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# Epoch 126/150
# 100/100 [==============================] - 51s 514ms/step - loss: 0.2352 - peak_signal_noise_ratio: 67.3383 - val_loss: 0.2545 - val_peak_signal_noise_ratio: 66.0689
# Epoch 127/150
# 100/100 [==============================] - 52s 523ms/step - loss: 0.2335 - peak_signal_noise_ratio: 67.4065 - val_loss: 0.2552 - val_peak_signal_noise_ratio: 66.0991
# Epoch 128/150
# 100/100 [==============================] - 51s 511ms/step - loss: 0.2355 - peak_signal_noise_ratio: 67.4158 - val_loss: 0.2631 - val_peak_signal_noise_ratio: 65.5378
# Epoch 129/150
# 100/100 [==============================] - 52s 515ms/step - loss: 0.2327 - peak_signal_noise_ratio: 67.5745 - val_loss: 0.2549 - val_peak_signal_noise_ratio: 66.1586
# Epoch 130/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.2340 - peak_signal_noise_ratio: 67.5165 - val_loss: 0.2653 - val_peak_signal_noise_ratio: 65.3667
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 4.768371461572052e-11.
# Epoch 131/150
# 100/100 [==============================] - 51s 512ms/step - loss: 0.2363 - peak_signal_noise_ratio: 67.4345 - val_loss: 0.2523 - val_peak_signal_noise_ratio: 66.2869
# Epoch 132/150
# 100/100 [==============================] - 54s 545ms/step - loss: 0.2303 - peak_signal_noise_ratio: 67.6900 - val_loss: 0.2565 - val_peak_signal_noise_ratio: 65.8714
# Epoch 133/150
# 100/100 [==============================] - 52s 516ms/step - loss: 0.2335 - peak_signal_noise_ratio: 67.3606 - val_loss: 0.2553 - val_peak_signal_noise_ratio: 66.0318
# Epoch 134/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.2358 - peak_signal_noise_ratio: 67.4224 - val_loss: 0.2561 - val_peak_signal_noise_ratio: 66.4148
# Epoch 135/150
# 100/100 [==============================] - 54s 542ms/step - loss: 0.2307 - peak_signal_noise_ratio: 67.7672 - val_loss: 0.2574 - val_peak_signal_noise_ratio: 65.9166
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# Epoch 136/150
# 100/100 [==============================] - 54s 543ms/step - loss: 0.2291 - peak_signal_noise_ratio: 67.8465 - val_loss: 0.2630 - val_peak_signal_noise_ratio: 65.9343
# Epoch 137/150
# 100/100 [==============================] - 55s 552ms/step - loss: 0.2377 - peak_signal_noise_ratio: 67.1045 - val_loss: 0.2630 - val_peak_signal_noise_ratio: 65.7021
# Epoch 138/150
# 100/100 [==============================] - 55s 547ms/step - loss: 0.2318 - peak_signal_noise_ratio: 67.6194 - val_loss: 0.2542 - val_peak_signal_noise_ratio: 66.5171
# Epoch 139/150
# 100/100 [==============================] - 57s 570ms/step - loss: 0.2357 - peak_signal_noise_ratio: 67.3249 - val_loss: 0.2542 - val_peak_signal_noise_ratio: 66.1943
# Epoch 140/150
# 100/100 [==============================] - 56s 558ms/step - loss: 0.2359 - peak_signal_noise_ratio: 67.3087 - val_loss: 0.2609 - val_peak_signal_noise_ratio: 65.5305
#
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 1.192092865393013e-11.
# Epoch 141/150
# 100/100 [==============================] - 58s 579ms/step - loss: 0.2340 - peak_signal_noise_ratio: 67.3175 - val_loss: 0.2571 - val_peak_signal_noise_ratio: 66.0452
# Epoch 142/150
# 100/100 [==============================] - 62s 622ms/step - loss: 0.2370 - peak_signal_noise_ratio: 67.1590 - val_loss: 0.2643 - val_peak_signal_noise_ratio: 65.6080
# Epoch 143/150
# 100/100 [==============================] - 61s 606ms/step - loss: 0.2362 - peak_signal_noise_ratio: 67.3766 - val_loss: 0.2606 - val_peak_signal_noise_ratio: 65.5132
# Epoch 144/150
# 100/100 [==============================] - 65s 653ms/step - loss: 0.2355 - peak_signal_noise_ratio: 67.4788 - val_loss: 0.2538 - val_peak_signal_noise_ratio: 66.2887
# Epoch 145/150
# 100/100 [==============================] - 59s 590ms/step - loss: 0.2363 - peak_signal_noise_ratio: 67.2357 - val_loss: 0.2583 - val_peak_signal_noise_ratio: 66.0385
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# Epoch 146/150
# 100/100 [==============================] - 58s 577ms/step - loss: 0.2334 - peak_signal_noise_ratio: 67.5385 - val_loss: 0.2580 - val_peak_signal_noise_ratio: 65.7907
# Epoch 147/150
# 100/100 [==============================] - 56s 558ms/step - loss: 0.2347 - peak_signal_noise_ratio: 67.3872 - val_loss: 0.2539 - val_peak_signal_noise_ratio: 66.1881
# Epoch 148/150
# 100/100 [==============================] - 53s 533ms/step - loss: 0.2355 - peak_signal_noise_ratio: 67.5436 - val_loss: 0.2580 - val_peak_signal_noise_ratio: 66.0885
# Epoch 149/150
# 100/100 [==============================] - 53s 534ms/step - loss: 0.2350 - peak_signal_noise_ratio: 67.4201 - val_loss: 0.2544 - val_peak_signal_noise_ratio: 66.2922
# Epoch 150/150
# 100/100 [==============================] - 53s 529ms/step - loss: 0.2354 - peak_signal_noise_ratio: 67.3503 - val_loss: 0.2504 - val_peak_signal_noise_ratio: 66.5710
#
# Epoch 00150: ReduceLROnPlateau reducing learning rate to 2.9802321634825324e-12.

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/loss_over_epochs"+str(num_epochs)+"_"+"Regularised_MIRNET.png")
plt.show()


plt.plot(history.history["peak_signal_noise_ratio"], label="train_psnr")
plt.plot(history.history["val_peak_signal_noise_ratio"], label="val_psnr")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.title("Train and Validation PSNR Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/psnr_over_epochs"+str(num_epochs)+"_"+"Regularised_MIRNET.png")
plt.show()

# %% [markdown]
# ## Inference

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %% [markdown]
# ### Inference on Test Images
#
# We compare the test images from LOLDataset enhanced by MIRNet with images
# enhanced via the `PIL.ImageOps.autocontrast()` function.

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )

# %%
model.save("models/mirnet_model_Regularised_MIRNET_epochs"+"_"+str(num_epochs)+"_"+str(MAX_TRAIN_IMAGES)+".h5")

# %%
original_image = Image.open("test2.jpg")
original_image = original_image.resize((256, 256))
enhanced_image = infer(original_image)
plot_results(
    [original_image, ImageOps.autocontrast(original_image), enhanced_image],
    ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
    (20, 12),
)

# %%
original_image = Image.open("test.jpg")
original_image = original_image.resize((256, 256))
enhanced_image = infer(original_image)
plot_results(
    [original_image, ImageOps.autocontrast(original_image), enhanced_image],
    ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
    (20, 12),
)
