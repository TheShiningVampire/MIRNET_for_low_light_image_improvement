# %% [markdown]
# # Low-light image enhancement using MIRNet
#
# **Author:** [Soumik Rakshit](http://github.com/soumik12345)<br>
# **Date created:** 2021/09/11<br>
# **Last modified:** 2021/09/15<br>
# **Description:** Implementing the MIRNet architecture for low-light image enhancement.

# %% [markdown]
# ## Introduction
#
# With the goal of recovering high-quality image content from its degraded version, image
# restoration enjoys numerous applications, such as in
# photography, security, medical imaging, and remote sensing. In this example, we implement the
# **MIRNet** model for low-light image enhancement, a fully-convolutional architecture that
# learns an enriched set of
# features that combines contextual information from multiple scales, while
# simultaneously preserving the high-resolution spatial details.
#
# ### References:
#
# - [Learning Enriched Features for Real Image Restoration and Enhancement](https://arxiv.org/abs/2003.06792)
# - [The Retinex Theory of Color Vision](http://www.cnbc.cmu.edu/~tai/cp_papers/E.Land_Retinex_Theory_ScientifcAmerican.pdf)
# - [Two deterministic half-quadratic regularization algorithms for computed imaging](https://ieeexplore.ieee.org/document/413553)

# %% [markdown]
# ## Downloading LOLDataset
#
# The **LoL Dataset** has been created for low-light image enhancement.
# It provides 485 images for training and 15 for testing. Each image pair in the dataset
# consists of a low-light input image and its corresponding well-exposed reference image.

# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6

# %%
# !unzip -q lol_dataset.zip

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# We use 300 image pairs from the LoL Dataset's training set for training,
# and we use the remaining 185 image pairs for validation.
# We generate random crops of size `128 x 128` from the image pairs to be
# used for both training and validation.

# %%
random.seed(10)

IMAGE_SIZE = 64
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 400


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    enhanced_w = low_w
    enhanced_h = low_h
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        enhanced_h : enhanced_h + IMAGE_SIZE, enhanced_w : enhanced_w + IMAGE_SIZE
    ]
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>
# Val Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## MIRNet Model
#
# Here are the main features of the MIRNet model:
#
# - A feature extraction model that computes a complementary set of features across multiple
# spatial scales, while maintaining the original high-resolution features to preserve
# precise spatial details.
# - A regularly repeated mechanism for information exchange, where the features across
# multi-resolution branches are progressively fused together for improved representation
# learning.
# - A new approach to fuse multi-scale features using a selective kernel network
# that dynamically combines variable receptive fields and faithfully preserves
# the original feature information at each spatial resolution.
# - A recursive residual design that progressively breaks down the input signal
# in order to simplify the overall learning process, and allows the construction
# of very deep networks.
#
#
# ![](https://raw.githubusercontent.com/soumik12345/MIRNet/master/assets/mirnet_architecture.png)

# %% [markdown]
# ### Selective Kernel Feature Fusion
#
# The Selective Kernel Feature Fusion or SKFF module performs dynamic adjustment of
# receptive fields via two operations: **Fuse** and **Select**. The Fuse operator generates
# global feature descriptors by combining the information from multi-resolution streams.
# The Select operator uses these descriptors to recalibrate the feature maps (of different
# streams) followed by their aggregation.
#
# **Fuse**: The SKFF receives inputs from three parallel convolution streams carrying
# different scales of information. We first combine these multi-scale features using an
# element-wise sum, on which we apply Global Average Pooling (GAP) across the spatial
# dimension. Next, we apply a channel- downscaling convolution layer to generate a compact
# feature representation which passes through three parallel channel-upscaling convolution
# layers (one for each resolution stream) and provides us with three feature descriptors.
#
# **Select**: This operator applies the softmax function to the feature descriptors to
# obtain the corresponding activations that are used to adaptively recalibrate multi-scale
# feature maps. The aggregated features are defined as the sum of product of the corresponding
# multi-scale feature and the feature descriptor.
#
# ![](https://i.imgur.com/7U6ixF6.png)

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
    return aggregated_feature

# %% [markdown]
# ### Dual Attention Unit
#
# The Dual Attention Unit or DAU is used to extract features in the convolutional streams.
# While the SKFF block fuses information across multi-resolution branches, we also need a
# mechanism to share information within a feature tensor, both along the spatial and the
# channel dimensions which is done by the DAU block. The DAU suppresses less useful
# features and only allows more informative ones to pass further. This feature
# recalibration is achieved by using **Channel Attention** and **Spatial Attention**
# mechanisms.
#
# The **Channel Attention** branch exploits the inter-channel relationships of the
# convolutional feature maps by applying squeeze and excitation operations. Given a feature
# map, the squeeze operation applies Global Average Pooling across spatial dimensions to
# encode global context, thus yielding a feature descriptor. The excitation operator passes
# this feature descriptor through two convolutional layers followed by the sigmoid gating
# and generates activations. Finally, the output of Channel Attention branch is obtained by
# rescaling the input feature map with the output activations.
#
# The **Spatial Attention** branch is designed to exploit the inter-spatial dependencies of
# convolutional features. The goal of Spatial Attention is to generate a spatial attention
# map and use it to recalibrate the incoming features. To generate the spatial attention
# map, the Spatial Attention branch first independently applies Global Average Pooling and
# Max Pooling operations on input features along the channel dimensions and concatenates
# the outputs to form a resultant feature map which is then passed through a convolution
# and sigmoid activation to obtain the spatial attention map. This spatial attention map is
# then used to rescale the input feature map.
#
# ![](https://i.imgur.com/Dl0IwQs.png)

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = layers.Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# ### Multi-Scale Residual Block
#
# The Multi-Scale Residual Block is capable of generating a spatially-precise output by
# maintaining high-resolution representations, while receiving rich contextual information
# from low-resolutions. The MRB consists of multiple (three in this paper)
# fully-convolutional streams connected in parallel. It allows information exchange across
# parallel streams in order to consolidate the high-resolution features with the help of
# low-resolution features, and vice versa. The MIRNet employs a recursive residual design
# (with skip connections) to ease the flow of information during the learning process. In
# order to maintain the residual nature of our architecture, residual resizing modules are
# used to perform downsampling and upsampling operations that are used in the Multi-scale
# Residual Block.
#
# ![](https://i.imgur.com/wzZKV57.png)

# %%
# Recursive Residual Modules


def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %% [markdown]
# ### MIRNet Model

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=32)

# %% [markdown]
# ## Training
#
# - We train MIRNet using **Charbonnier Loss** as the loss function and **Adam
# Optimizer** with a learning rate of `1e-4`.
# - We use **Peak Signal Noise Ratio** or PSNR as a metric which is an expression for the
# ratio between the maximum possible value (power) of a signal and the power of distorting
# noise that affects the quality of its representation.

# %%
num_epochs = 150
lr = 1e-4


def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=lr)

# def scheduler(epoch, lr):
#   # # exponential decay
#   # if epoch < 20:
#   #   return lr
#   # else:
#   #   # return lr * tf.math.exp(-0.1)

#   # # step decay
#   # drop_rate = 0.5
#   # epoch_drop = 10
#   # return lr * pow(drop_rate, tf.math.floor(epoch/epoch_drop))

#   # time-based decay
#   decay = 1e-4/150  # chosen by experimentation
#   return lr * 1/(1 + decay*epoch)


tb_callback = keras.callbacks.TensorBoard(log_dir="./logs/ReduceLROnPlateau", histogram_freq=1)
# callback = keras.callbacks.LearningRateScheduler(scheduler, 1)

model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        ),
        tb_callback,
    ],
)


# history = model.fit(
#     train_dataset,
#     validation_data=val_dataset,
#     epochs=num_epochs,
#     callbacks=[callback, tb_callback]
# )
# Out:
# C:\Users\Vinit\anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/150
# 100/100 [==============================] - 74s 364ms/step - loss: 0.2017 - peak_signal_noise_ratio: 62.3205 - val_loss: 0.1821 - val_peak_signal_noise_ratio: 62.6712
# Epoch 2/150
# 100/100 [==============================] - 24s 245ms/step - loss: 0.1616 - peak_signal_noise_ratio: 63.9229 - val_loss: 0.1573 - val_peak_signal_noise_ratio: 64.2135
# Epoch 3/150
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1518 - peak_signal_noise_ratio: 64.4380 - val_loss: 0.1523 - val_peak_signal_noise_ratio: 64.6499
# Epoch 4/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1473 - peak_signal_noise_ratio: 64.7622 - val_loss: 0.1530 - val_peak_signal_noise_ratio: 64.7054
# Epoch 5/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1357 - peak_signal_noise_ratio: 65.3769 - val_loss: 0.1584 - val_peak_signal_noise_ratio: 64.4974
# Epoch 6/150
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1404 - peak_signal_noise_ratio: 65.2821 - val_loss: 0.1580 - val_peak_signal_noise_ratio: 64.4407
# Epoch 7/150
# 100/100 [==============================] - 25s 244ms/step - loss: 0.1368 - peak_signal_noise_ratio: 65.6074 - val_loss: 0.1513 - val_peak_signal_noise_ratio: 65.0571
# Epoch 8/150
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1392 - peak_signal_noise_ratio: 65.5843 - val_loss: 0.1553 - val_peak_signal_noise_ratio: 64.8278
# Epoch 9/150
# 100/100 [==============================] - 28s 280ms/step - loss: 0.1361 - peak_signal_noise_ratio: 65.7464 - val_loss: 0.1608 - val_peak_signal_noise_ratio: 64.8766
# Epoch 10/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1372 - peak_signal_noise_ratio: 65.6642 - val_loss: 0.1716 - val_peak_signal_noise_ratio: 64.0917
# Epoch 11/150
# 100/100 [==============================] - 28s 275ms/step - loss: 0.1276 - peak_signal_noise_ratio: 66.4664 - val_loss: 0.1651 - val_peak_signal_noise_ratio: 64.3344
# Epoch 12/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1289 - peak_signal_noise_ratio: 66.2945 - val_loss: 0.1590 - val_peak_signal_noise_ratio: 65.0553
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 13/150
# 100/100 [==============================] - 28s 283ms/step - loss: 0.1329 - peak_signal_noise_ratio: 66.0061 - val_loss: 0.1633 - val_peak_signal_noise_ratio: 64.5666
# Epoch 14/150
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1341 - peak_signal_noise_ratio: 65.9202 - val_loss: 0.1536 - val_peak_signal_noise_ratio: 65.0347
# Epoch 15/150
# 100/100 [==============================] - 28s 277ms/step - loss: 0.1227 - peak_signal_noise_ratio: 66.5797 - val_loss: 0.1616 - val_peak_signal_noise_ratio: 64.6785
# Epoch 16/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1187 - peak_signal_noise_ratio: 66.9948 - val_loss: 0.1509 - val_peak_signal_noise_ratio: 65.3036
# Epoch 17/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1265 - peak_signal_noise_ratio: 66.5602 - val_loss: 0.1552 - val_peak_signal_noise_ratio: 65.1392
# Epoch 18/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1204 - peak_signal_noise_ratio: 66.9127 - val_loss: 0.1559 - val_peak_signal_noise_ratio: 64.8109
# Epoch 19/150
# 100/100 [==============================] - 26s 262ms/step - loss: 0.1211 - peak_signal_noise_ratio: 67.0162 - val_loss: 0.1432 - val_peak_signal_noise_ratio: 65.9980
# Epoch 20/150
# 100/100 [==============================] - 25s 250ms/step - loss: 0.1260 - peak_signal_noise_ratio: 66.6823 - val_loss: 0.1608 - val_peak_signal_noise_ratio: 64.8488
# Epoch 21/150
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1212 - peak_signal_noise_ratio: 66.8556 - val_loss: 0.1417 - val_peak_signal_noise_ratio: 65.9102
# Epoch 22/150
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1237 - peak_signal_noise_ratio: 66.7463 - val_loss: 0.1414 - val_peak_signal_noise_ratio: 65.9789
# Epoch 23/150
# 100/100 [==============================] - 25s 252ms/step - loss: 0.1240 - peak_signal_noise_ratio: 66.6896 - val_loss: 0.1406 - val_peak_signal_noise_ratio: 65.7030
# Epoch 24/150
# 100/100 [==============================] - 25s 252ms/step - loss: 0.1246 - peak_signal_noise_ratio: 66.7827 - val_loss: 0.1490 - val_peak_signal_noise_ratio: 65.2996
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 25/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1212 - peak_signal_noise_ratio: 66.9371 - val_loss: 0.1358 - val_peak_signal_noise_ratio: 65.8457
# Epoch 26/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1208 - peak_signal_noise_ratio: 66.8729 - val_loss: 0.1395 - val_peak_signal_noise_ratio: 65.8453
# Epoch 27/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1192 - peak_signal_noise_ratio: 67.1478 - val_loss: 0.1456 - val_peak_signal_noise_ratio: 65.6571
# Epoch 28/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1170 - peak_signal_noise_ratio: 67.2176 - val_loss: 0.1319 - val_peak_signal_noise_ratio: 66.4835
# Epoch 29/150
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1205 - peak_signal_noise_ratio: 66.9086 - val_loss: 0.1327 - val_peak_signal_noise_ratio: 66.2330
# Epoch 30/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1189 - peak_signal_noise_ratio: 67.2323 - val_loss: 0.1331 - val_peak_signal_noise_ratio: 66.2194
# Epoch 31/150
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1194 - peak_signal_noise_ratio: 67.1904 - val_loss: 0.1333 - val_peak_signal_noise_ratio: 66.4147
# Epoch 32/150
# 100/100 [==============================] - 26s 263ms/step - loss: 0.1155 - peak_signal_noise_ratio: 67.4235 - val_loss: 0.1389 - val_peak_signal_noise_ratio: 66.0011
# Epoch 33/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1191 - peak_signal_noise_ratio: 67.2150 - val_loss: 0.1414 - val_peak_signal_noise_ratio: 65.4653
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 34/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1173 - peak_signal_noise_ratio: 67.3586 - val_loss: 0.1274 - val_peak_signal_noise_ratio: 66.2618
# Epoch 35/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1141 - peak_signal_noise_ratio: 67.4898 - val_loss: 0.1279 - val_peak_signal_noise_ratio: 66.5432
# Epoch 36/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1195 - peak_signal_noise_ratio: 67.0557 - val_loss: 0.1286 - val_peak_signal_noise_ratio: 66.5726
# Epoch 37/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1189 - peak_signal_noise_ratio: 67.1516 - val_loss: 0.1293 - val_peak_signal_noise_ratio: 66.4098
# Epoch 38/150
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1152 - peak_signal_noise_ratio: 67.4154 - val_loss: 0.1345 - val_peak_signal_noise_ratio: 66.0304
# Epoch 39/150
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1137 - peak_signal_noise_ratio: 67.4414 - val_loss: 0.1211 - val_peak_signal_noise_ratio: 67.1180
# Epoch 40/150
# 100/100 [==============================] - 28s 282ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.5250 - val_loss: 0.1265 - val_peak_signal_noise_ratio: 66.5353
# Epoch 41/150
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1150 - peak_signal_noise_ratio: 67.4079 - val_loss: 0.1373 - val_peak_signal_noise_ratio: 65.5876
# Epoch 42/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.5277 - val_loss: 0.1344 - val_peak_signal_noise_ratio: 65.9493
# Epoch 43/150
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1178 - peak_signal_noise_ratio: 67.3853 - val_loss: 0.1332 - val_peak_signal_noise_ratio: 66.2515
# Epoch 44/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1160 - peak_signal_noise_ratio: 67.3102 - val_loss: 0.1298 - val_peak_signal_noise_ratio: 66.5108
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 45/150
# 100/100 [==============================] - 25s 252ms/step - loss: 0.1143 - peak_signal_noise_ratio: 67.4573 - val_loss: 0.1273 - val_peak_signal_noise_ratio: 66.6500
# Epoch 46/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1169 - peak_signal_noise_ratio: 67.3031 - val_loss: 0.1231 - val_peak_signal_noise_ratio: 66.9238
# Epoch 47/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1166 - peak_signal_noise_ratio: 67.3854 - val_loss: 0.1340 - val_peak_signal_noise_ratio: 65.9784
# Epoch 48/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1097 - peak_signal_noise_ratio: 67.6797 - val_loss: 0.1267 - val_peak_signal_noise_ratio: 66.5706
# Epoch 49/150
# 100/100 [==============================] - 25s 247ms/step - loss: 0.1105 - peak_signal_noise_ratio: 67.8917 - val_loss: 0.1221 - val_peak_signal_noise_ratio: 67.0418
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 50/150
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1141 - peak_signal_noise_ratio: 67.5195 - val_loss: 0.1277 - val_peak_signal_noise_ratio: 66.2753
# Epoch 51/150
# 100/100 [==============================] - 25s 250ms/step - loss: 0.1110 - peak_signal_noise_ratio: 67.6751 - val_loss: 0.1296 - val_peak_signal_noise_ratio: 66.4411
# Epoch 52/150
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.7626 - val_loss: 0.1340 - val_peak_signal_noise_ratio: 66.1420
# Epoch 53/150
# 100/100 [==============================] - 25s 253ms/step - loss: 0.1095 - peak_signal_noise_ratio: 67.7611 - val_loss: 0.1256 - val_peak_signal_noise_ratio: 66.7496
# Epoch 54/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1103 - peak_signal_noise_ratio: 67.6611 - val_loss: 0.1357 - val_peak_signal_noise_ratio: 66.0695
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 55/150
# 100/100 [==============================] - 25s 248ms/step - loss: 0.1118 - peak_signal_noise_ratio: 67.7436 - val_loss: 0.1271 - val_peak_signal_noise_ratio: 66.7114
# Epoch 56/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.7298 - val_loss: 0.1391 - val_peak_signal_noise_ratio: 65.9961
# Epoch 57/150
# 100/100 [==============================] - 26s 255ms/step - loss: 0.1093 - peak_signal_noise_ratio: 67.8303 - val_loss: 0.1328 - val_peak_signal_noise_ratio: 66.2757
# Epoch 58/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1052 - peak_signal_noise_ratio: 68.0894 - val_loss: 0.1389 - val_peak_signal_noise_ratio: 65.8552
# Epoch 59/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1104 - peak_signal_noise_ratio: 67.6855 - val_loss: 0.1300 - val_peak_signal_noise_ratio: 66.3740
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 60/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1162 - peak_signal_noise_ratio: 67.3828 - val_loss: 0.1302 - val_peak_signal_noise_ratio: 66.3629
# Epoch 61/150
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1080 - peak_signal_noise_ratio: 68.0348 - val_loss: 0.1326 - val_peak_signal_noise_ratio: 66.2719
# Epoch 62/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.7183 - val_loss: 0.1345 - val_peak_signal_noise_ratio: 65.9958
# Epoch 63/150
# 100/100 [==============================] - 27s 265ms/step - loss: 0.1102 - peak_signal_noise_ratio: 67.8097 - val_loss: 0.1370 - val_peak_signal_noise_ratio: 66.0028
# Epoch 64/150
# 100/100 [==============================] - 25s 254ms/step - loss: 0.1146 - peak_signal_noise_ratio: 67.5876 - val_loss: 0.1321 - val_peak_signal_noise_ratio: 66.3463
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 65/150
# 100/100 [==============================] - 25s 251ms/step - loss: 0.1111 - peak_signal_noise_ratio: 67.7912 - val_loss: 0.1329 - val_peak_signal_noise_ratio: 66.2283
# Epoch 66/150
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1131 - peak_signal_noise_ratio: 67.4337 - val_loss: 0.1259 - val_peak_signal_noise_ratio: 66.5085
# Epoch 67/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.7339 - val_loss: 0.1289 - val_peak_signal_noise_ratio: 66.5553
# Epoch 68/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1087 - peak_signal_noise_ratio: 67.9791 - val_loss: 0.1359 - val_peak_signal_noise_ratio: 66.0695
# Epoch 69/150
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1127 - peak_signal_noise_ratio: 67.6631 - val_loss: 0.1268 - val_peak_signal_noise_ratio: 66.6070
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 70/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1141 - peak_signal_noise_ratio: 67.6562 - val_loss: 0.1369 - val_peak_signal_noise_ratio: 66.0645
# Epoch 71/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1092 - peak_signal_noise_ratio: 68.0103 - val_loss: 0.1348 - val_peak_signal_noise_ratio: 66.2212
# Epoch 72/150
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1090 - peak_signal_noise_ratio: 67.8156 - val_loss: 0.1394 - val_peak_signal_noise_ratio: 65.6728
# Epoch 73/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1115 - peak_signal_noise_ratio: 67.7087 - val_loss: 0.1340 - val_peak_signal_noise_ratio: 66.5221
# Epoch 74/150
# 100/100 [==============================] - 27s 265ms/step - loss: 0.1098 - peak_signal_noise_ratio: 67.8625 - val_loss: 0.1314 - val_peak_signal_noise_ratio: 66.3365
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 75/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1134 - peak_signal_noise_ratio: 67.6043 - val_loss: 0.1343 - val_peak_signal_noise_ratio: 66.3400
# Epoch 76/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1099 - peak_signal_noise_ratio: 67.8151 - val_loss: 0.1325 - val_peak_signal_noise_ratio: 66.1681
# Epoch 77/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1090 - peak_signal_noise_ratio: 67.8061 - val_loss: 0.1351 - val_peak_signal_noise_ratio: 66.0483
# Epoch 78/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1072 - peak_signal_noise_ratio: 67.9441 - val_loss: 0.1411 - val_peak_signal_noise_ratio: 65.7081
# Epoch 79/150
# 100/100 [==============================] - 26s 260ms/step - loss: 0.1102 - peak_signal_noise_ratio: 67.6811 - val_loss: 0.1360 - val_peak_signal_noise_ratio: 66.0079
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 80/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1103 - peak_signal_noise_ratio: 67.7920 - val_loss: 0.1386 - val_peak_signal_noise_ratio: 65.7627
# Epoch 81/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1084 - peak_signal_noise_ratio: 68.0521 - val_loss: 0.1455 - val_peak_signal_noise_ratio: 65.3115
# Epoch 82/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1106 - peak_signal_noise_ratio: 67.7922 - val_loss: 0.1431 - val_peak_signal_noise_ratio: 65.5759
# Epoch 83/150
# 100/100 [==============================] - 26s 264ms/step - loss: 0.1051 - peak_signal_noise_ratio: 68.1700 - val_loss: 0.1393 - val_peak_signal_noise_ratio: 66.1144
# Epoch 84/150
# 100/100 [==============================] - 26s 258ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.5621 - val_loss: 0.1349 - val_peak_signal_noise_ratio: 66.0735
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 85/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1112 - peak_signal_noise_ratio: 67.6480 - val_loss: 0.1316 - val_peak_signal_noise_ratio: 66.1345
# Epoch 86/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1139 - peak_signal_noise_ratio: 67.5075 - val_loss: 0.1295 - val_peak_signal_noise_ratio: 66.7666
# Epoch 87/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.5767 - val_loss: 0.1350 - val_peak_signal_noise_ratio: 66.0315
# Epoch 88/150
# 100/100 [==============================] - 26s 256ms/step - loss: 0.1126 - peak_signal_noise_ratio: 67.5503 - val_loss: 0.1305 - val_peak_signal_noise_ratio: 66.5415
# Epoch 89/150
# 100/100 [==============================] - 27s 265ms/step - loss: 0.1091 - peak_signal_noise_ratio: 67.8293 - val_loss: 0.1399 - val_peak_signal_noise_ratio: 66.1116
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 90/150
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1097 - peak_signal_noise_ratio: 67.8562 - val_loss: 0.1319 - val_peak_signal_noise_ratio: 66.3541
# Epoch 91/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1090 - peak_signal_noise_ratio: 67.8336 - val_loss: 0.1358 - val_peak_signal_noise_ratio: 65.8473
# Epoch 92/150
# 100/100 [==============================] - 26s 257ms/step - loss: 0.1083 - peak_signal_noise_ratio: 67.9306 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.3164
# Epoch 93/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.6519 - val_loss: 0.1269 - val_peak_signal_noise_ratio: 66.3615
# Epoch 94/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1087 - peak_signal_noise_ratio: 67.8513 - val_loss: 0.1342 - val_peak_signal_noise_ratio: 66.1001
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 95/150
# 100/100 [==============================] - 27s 265ms/step - loss: 0.1101 - peak_signal_noise_ratio: 67.7755 - val_loss: 0.1328 - val_peak_signal_noise_ratio: 66.0406
# Epoch 96/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1083 - peak_signal_noise_ratio: 67.8652 - val_loss: 0.1369 - val_peak_signal_noise_ratio: 66.0806
# Epoch 97/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1118 - peak_signal_noise_ratio: 67.7420 - val_loss: 0.1327 - val_peak_signal_noise_ratio: 66.4713
# Epoch 98/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1067 - peak_signal_noise_ratio: 68.1116 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 65.8959
# Epoch 99/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1116 - peak_signal_noise_ratio: 67.7748 - val_loss: 0.1424 - val_peak_signal_noise_ratio: 65.6116
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 100/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1121 - peak_signal_noise_ratio: 67.8060 - val_loss: 0.1287 - val_peak_signal_noise_ratio: 66.5239
# Epoch 101/150
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1130 - peak_signal_noise_ratio: 67.5243 - val_loss: 0.1287 - val_peak_signal_noise_ratio: 66.6687
# Epoch 102/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1141 - peak_signal_noise_ratio: 67.5538 - val_loss: 0.1267 - val_peak_signal_noise_ratio: 66.6089
# Epoch 103/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1114 - peak_signal_noise_ratio: 67.7811 - val_loss: 0.1451 - val_peak_signal_noise_ratio: 65.3340
# Epoch 104/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1051 - peak_signal_noise_ratio: 68.2522 - val_loss: 0.1424 - val_peak_signal_noise_ratio: 65.7326
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 105/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1108 - peak_signal_noise_ratio: 67.6637 - val_loss: 0.1304 - val_peak_signal_noise_ratio: 66.4732
# Epoch 106/150
# 100/100 [==============================] - 26s 262ms/step - loss: 0.1128 - peak_signal_noise_ratio: 67.5777 - val_loss: 0.1426 - val_peak_signal_noise_ratio: 65.6356
# Epoch 107/150
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1086 - peak_signal_noise_ratio: 67.8330 - val_loss: 0.1333 - val_peak_signal_noise_ratio: 66.3651
# Epoch 108/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.9654 - val_loss: 0.1339 - val_peak_signal_noise_ratio: 66.2673
# Epoch 109/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.7685 - val_loss: 0.1336 - val_peak_signal_noise_ratio: 66.0614
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 110/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1077 - peak_signal_noise_ratio: 67.8622 - val_loss: 0.1358 - val_peak_signal_noise_ratio: 66.1340
# Epoch 111/150
# 100/100 [==============================] - 28s 279ms/step - loss: 0.1055 - peak_signal_noise_ratio: 68.0332 - val_loss: 0.1313 - val_peak_signal_noise_ratio: 66.1465
# Epoch 112/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1145 - peak_signal_noise_ratio: 67.5514 - val_loss: 0.1423 - val_peak_signal_noise_ratio: 65.4031
# Epoch 113/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1103 - peak_signal_noise_ratio: 67.7530 - val_loss: 0.1369 - val_peak_signal_noise_ratio: 66.0209
# Epoch 114/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1083 - peak_signal_noise_ratio: 67.9321 - val_loss: 0.1371 - val_peak_signal_noise_ratio: 65.8756
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# Epoch 115/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1140 - peak_signal_noise_ratio: 67.3736 - val_loss: 0.1464 - val_peak_signal_noise_ratio: 65.2683
# Epoch 116/150
# 100/100 [==============================] - 27s 269ms/step - loss: 0.1112 - peak_signal_noise_ratio: 67.6271 - val_loss: 0.1315 - val_peak_signal_noise_ratio: 66.5616
# Epoch 117/150
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1035 - peak_signal_noise_ratio: 68.2068 - val_loss: 0.1407 - val_peak_signal_noise_ratio: 65.9696
# Epoch 118/150
# 100/100 [==============================] - 26s 259ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.5535 - val_loss: 0.1329 - val_peak_signal_noise_ratio: 66.3630
# Epoch 119/150
# 100/100 [==============================] - 28s 277ms/step - loss: 0.1100 - peak_signal_noise_ratio: 67.8283 - val_loss: 0.1369 - val_peak_signal_noise_ratio: 66.1160
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 1.9073485846288207e-10.
# Epoch 120/150
# 100/100 [==============================] - 26s 261ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.7636 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.1575
# Epoch 121/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.7025 - val_loss: 0.1379 - val_peak_signal_noise_ratio: 65.8885
# Epoch 122/150
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1071 - peak_signal_noise_ratio: 67.9101 - val_loss: 0.1378 - val_peak_signal_noise_ratio: 66.0322
# Epoch 123/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1092 - peak_signal_noise_ratio: 67.8285 - val_loss: 0.1336 - val_peak_signal_noise_ratio: 66.2129
# Epoch 124/150
# 100/100 [==============================] - 26s 263ms/step - loss: 0.1106 - peak_signal_noise_ratio: 67.5927 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.2428
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# Epoch 125/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1103 - peak_signal_noise_ratio: 67.7073 - val_loss: 0.1373 - val_peak_signal_noise_ratio: 65.8269
# Epoch 126/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1108 - peak_signal_noise_ratio: 67.6790 - val_loss: 0.1237 - val_peak_signal_noise_ratio: 66.9961
# Epoch 127/150
# 100/100 [==============================] - 28s 275ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.4718 - val_loss: 0.1277 - val_peak_signal_noise_ratio: 66.5687
# Epoch 128/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1081 - peak_signal_noise_ratio: 67.8612 - val_loss: 0.1331 - val_peak_signal_noise_ratio: 66.4147
# Epoch 129/150
# 100/100 [==============================] - 27s 274ms/step - loss: 0.1117 - peak_signal_noise_ratio: 67.6640 - val_loss: 0.1312 - val_peak_signal_noise_ratio: 66.0702
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 4.768371461572052e-11.
# Epoch 130/150
# 100/100 [==============================] - 27s 267ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.7385 - val_loss: 0.1306 - val_peak_signal_noise_ratio: 66.4516
# Epoch 131/150
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1074 - peak_signal_noise_ratio: 67.9822 - val_loss: 0.1341 - val_peak_signal_noise_ratio: 65.9719
# Epoch 132/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.8625 - val_loss: 0.1280 - val_peak_signal_noise_ratio: 66.5713
# Epoch 133/150
# 100/100 [==============================] - 27s 271ms/step - loss: 0.1078 - peak_signal_noise_ratio: 68.0607 - val_loss: 0.1286 - val_peak_signal_noise_ratio: 66.6120
# Epoch 134/150
# 100/100 [==============================] - 26s 263ms/step - loss: 0.1100 - peak_signal_noise_ratio: 67.8701 - val_loss: 0.1339 - val_peak_signal_noise_ratio: 66.2327
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# Epoch 135/150
# 100/100 [==============================] - 27s 273ms/step - loss: 0.1128 - peak_signal_noise_ratio: 67.6545 - val_loss: 0.1270 - val_peak_signal_noise_ratio: 66.8358
# Epoch 136/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1161 - peak_signal_noise_ratio: 67.4033 - val_loss: 0.1380 - val_peak_signal_noise_ratio: 66.1631
# Epoch 137/150
# 100/100 [==============================] - 26s 263ms/step - loss: 0.1087 - peak_signal_noise_ratio: 67.9636 - val_loss: 0.1275 - val_peak_signal_noise_ratio: 66.5869
# Epoch 138/150
# 100/100 [==============================] - 25s 251ms/step - loss: 0.1104 - peak_signal_noise_ratio: 67.7404 - val_loss: 0.1397 - val_peak_signal_noise_ratio: 65.9643
# Epoch 139/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1140 - peak_signal_noise_ratio: 67.4314 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.3908
#
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 1.192092865393013e-11.
# Epoch 140/150
# 100/100 [==============================] - 28s 282ms/step - loss: 0.1092 - peak_signal_noise_ratio: 67.8106 - val_loss: 0.1320 - val_peak_signal_noise_ratio: 66.3051
# Epoch 141/150
# 100/100 [==============================] - 28s 275ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.6670 - val_loss: 0.1384 - val_peak_signal_noise_ratio: 65.9074
# Epoch 142/150
# 100/100 [==============================] - 27s 274ms/step - loss: 0.1098 - peak_signal_noise_ratio: 67.8568 - val_loss: 0.1271 - val_peak_signal_noise_ratio: 66.6057
# Epoch 143/150
# 100/100 [==============================] - 29s 284ms/step - loss: 0.1131 - peak_signal_noise_ratio: 67.5954 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.2888
# Epoch 144/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1170 - peak_signal_noise_ratio: 67.2282 - val_loss: 0.1325 - val_peak_signal_noise_ratio: 66.0598
#
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# Epoch 145/150
# 100/100 [==============================] - 27s 268ms/step - loss: 0.1094 - peak_signal_noise_ratio: 67.8640 - val_loss: 0.1324 - val_peak_signal_noise_ratio: 66.1776
# Epoch 146/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1121 - peak_signal_noise_ratio: 67.7337 - val_loss: 0.1313 - val_peak_signal_noise_ratio: 66.3395
# Epoch 147/150
# 100/100 [==============================] - 28s 276ms/step - loss: 0.1075 - peak_signal_noise_ratio: 67.9381 - val_loss: 0.1320 - val_peak_signal_noise_ratio: 66.2895
# Epoch 148/150
# 100/100 [==============================] - 27s 266ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.7309 - val_loss: 0.1375 - val_peak_signal_noise_ratio: 66.0023
# Epoch 149/150
# 100/100 [==============================] - 27s 270ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.7407 - val_loss: 0.1453 - val_peak_signal_noise_ratio: 65.4967
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 2.9802321634825324e-12.
# Epoch 150/150
# 100/100 [==============================] - 27s 272ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.7308 - val_loss: 0.1312 - val_peak_signal_noise_ratio: 66.3162

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/loss_over_epochs"+str(num_epochs)+"_"+"ReduceLROnPlateau.png")
plt.show()


plt.plot(history.history["peak_signal_noise_ratio"], label="train_psnr")
plt.plot(history.history["val_peak_signal_noise_ratio"], label="val_psnr")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.title("Train and Validation PSNR Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/psnr_over_epochs"+str(num_epochs)+"_"+"ReduceLROnPlateau.png")
plt.show()

# %% [markdown]
# ## Inference

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %% [markdown]
# ### Inference on Test Images
#
# We compare the test images from LOLDataset enhanced by MIRNet with images
# enhanced via the `PIL.ImageOps.autocontrast()` function.

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )

# %%
model.save("models/mirnet_model_ReduceLROnPlateau_epochs"+"_"+str(num_epochs)+"_"+str(MAX_TRAIN_IMAGES)+".h5")
