# %% [markdown]
# # Low-light image enhancement using MIRNet

# %% [markdown]
# ## Introduction
#
# With the goal of recovering high-quality image content from its degraded version, image
# restoration enjoys numerous applications, such as in
# photography, security, medical imaging, and remote sensing. In this example, we implement the
# **MIRNet** model for low-light image enhancement, a fully-convolutional architecture that
# learns an enriched set of
# features that combines contextual information from multiple scales, while
# simultaneously preserving the high-resolution spatial details.
#
# ### References:
#
# - [Learning Enriched Features for Real Image Restoration and Enhancement](https://arxiv.org/abs/2003.06792)
# - [The Retinex Theory of Color Vision](http://www.cnbc.cmu.edu/~tai/cp_papers/E.Land_Retinex_Theory_ScientifcAmerican.pdf)
# - [Two deterministic half-quadratic regularization algorithms for computed imaging](https://ieeexplore.ieee.org/document/413553)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Downloading LOLDataset
#
# The **LoL Dataset** has been created for low-light image enhancement.
# It provides 485 images for training and 15 for testing. Each image pair in the dataset
# consists of a low-light input image and its corresponding well-exposed reference image.

# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# %cd "/content/drive/MyDrive/EE610"

# %%
# #!gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# !unzip -q lol_dataset.zip

# %%
# !mkdir "checkpoint"

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# We use 300 image pairs from the LoL Dataset's training set for training,
# and we use the remaining 185 image pairs for validation.
# We generate random crops of size `128 x 128` from the image pairs to be
# used for both training and validation.

# %%
random.seed(10)

IMAGE_SIZE = 64
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 400


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    enhanced_w = low_w
    enhanced_h = low_h
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        enhanced_h : enhanced_h + IMAGE_SIZE, enhanced_w : enhanced_w + IMAGE_SIZE
    ]
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>
# Val Dataset: <BatchDataset shapes: ((4, None, None, 3), (4, None, None, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## MIRNet Model
#
# Here are the main features of the MIRNet model:
#
# - A feature extraction model that computes a complementary set of features across multiple
# spatial scales, while maintaining the original high-resolution features to preserve
# precise spatial details.
# - A regularly repeated mechanism for information exchange, where the features across
# multi-resolution branches are progressively fused together for improved representation
# learning.
# - A new approach to fuse multi-scale features using a selective kernel network
# that dynamically combines variable receptive fields and faithfully preserves
# the original feature information at each spatial resolution.
# - A recursive residual design that progressively breaks down the input signal
# in order to simplify the overall learning process, and allows the construction
# of very deep networks.
#
#
# ![](https://raw.githubusercontent.com/soumik12345/MIRNet/master/assets/mirnet_architecture.png)

# %% [markdown]
# ### Selective Kernel Feature Fusion
#
# The Selective Kernel Feature Fusion or SKFF module performs dynamic adjustment of
# receptive fields via two operations: **Fuse** and **Select**. The Fuse operator generates
# global feature descriptors by combining the information from multi-resolution streams.
# The Select operator uses these descriptors to recalibrate the feature maps (of different
# streams) followed by their aggregation.
#
# **Fuse**: The SKFF receives inputs from three parallel convolution streams carrying
# different scales of information. We first combine these multi-scale features using an
# element-wise sum, on which we apply Global Average Pooling (GAP) across the spatial
# dimension. Next, we apply a channel- downscaling convolution layer to generate a compact
# feature representation which passes through three parallel channel-upscaling convolution
# layers (one for each resolution stream) and provides us with three feature descriptors.
#
# **Select**: This operator applies the softmax function to the feature descriptors to
# obtain the corresponding activations that are used to adaptively recalibrate multi-scale
# feature maps. The aggregated features are defined as the sum of product of the corresponding
# multi-scale feature and the feature descriptor.
#
# ![](https://i.imgur.com/7U6ixF6.png)

# %%
# def selective_kernel_feature_fusion(
#     multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
# ):
#     channels = list(multi_scale_feature_1.shape)[-1]
#     combined_feature = layers.Add()(
#         [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
#     )
#     gap = layers.GlobalAveragePooling2D()(combined_feature)
#     channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
#     compact_feature_representation = layers.Conv2D(
#         filters=channels // 8, kernel_size=(1, 1), activation="relu"
#     )(channel_wise_statistics)
#     feature_descriptor_1 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_descriptor_2 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_descriptor_3 = layers.Conv2D(
#         channels, kernel_size=(1, 1), activation="softmax"
#     )(compact_feature_representation)
#     feature_1 = multi_scale_feature_1 * feature_descriptor_1
#     feature_2 = multi_scale_feature_2 * feature_descriptor_2
#     feature_3 = multi_scale_feature_3 * feature_descriptor_3
#     aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
#     return aggregated_feature

def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3, multi_scale_feature_4
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3, multi_scale_feature_4]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_4 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    feature_4 = multi_scale_feature_4 * feature_descriptor_4
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3, feature_4])
    return aggregated_feature

# %% [markdown]
# ### Dual Attention Unit
#
# The Dual Attention Unit or DAU is used to extract features in the convolutional streams.
# While the SKFF block fuses information across multi-resolution branches, we also need a
# mechanism to share information within a feature tensor, both along the spatial and the
# channel dimensions which is done by the DAU block. The DAU suppresses less useful
# features and only allows more informative ones to pass further. This feature
# recalibration is achieved by using **Channel Attention** and **Spatial Attention**
# mechanisms.
#
# The **Channel Attention** branch exploits the inter-channel relationships of the
# convolutional feature maps by applying squeeze and excitation operations. Given a feature
# map, the squeeze operation applies Global Average Pooling across spatial dimensions to
# encode global context, thus yielding a feature descriptor. The excitation operator passes
# this feature descriptor through two convolutional layers followed by the sigmoid gating
# and generates activations. Finally, the output of Channel Attention branch is obtained by
# rescaling the input feature map with the output activations.
#
# The **Spatial Attention** branch is designed to exploit the inter-spatial dependencies of
# convolutional features. The goal of Spatial Attention is to generate a spatial attention
# map and use it to recalibrate the incoming features. To generate the spatial attention
# map, the Spatial Attention branch first independently applies Global Average Pooling and
# Max Pooling operations on input features along the channel dimensions and concatenates
# the outputs to form a resultant feature map which is then passed through a convolution
# and sigmoid activation to obtain the spatial attention map. This spatial attention map is
# then used to rescale the input feature map.
#
# ![](https://i.imgur.com/Dl0IwQs.png)

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = layers.Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %% [markdown]
# ### Multi-Scale Residual Block
#
# The Multi-Scale Residual Block is capable of generating a spatially-precise output by
# maintaining high-resolution representations, while receiving rich contextual information
# from low-resolutions. The MRB consists of multiple (three in this paper)
# fully-convolutional streams connected in parallel. It allows information exchange across
# parallel streams in order to consolidate the high-resolution features with the help of
# low-resolution features, and vice versa. The MIRNet employs a recursive residual design
# (with skip connections) to ease the flow of information during the learning process. In
# order to maintain the residual nature of our architecture, residual resizing modules are
# used to perform downsampling and upsampling operations that are used in the Multi-scale
# Residual Block.
#
# ![](https://i.imgur.com/wzZKV57.png)

# %%
# Recursive Residual Modules


def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# # MRB Block
# def multi_scale_residual_block(input_tensor, channels):
#     # features
#     level1 = input_tensor
#     level2 = down_sampling_module(input_tensor)
#     level3 = down_sampling_module(level2)
#     # DAU
#     level1_dau = dual_attention_unit_block(level1)
#     level2_dau = dual_attention_unit_block(level2)
#     level3_dau = dual_attention_unit_block(level3)
#     # SKFF
#     level1_skff = selective_kernel_feature_fusion(
#         level1_dau,
#         up_sampling_module(level2_dau),
#         up_sampling_module(up_sampling_module(level3_dau)),
#     )
#     level2_skff = selective_kernel_feature_fusion(
#         down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
#     )
#     level3_skff = selective_kernel_feature_fusion(
#         down_sampling_module(down_sampling_module(level1_dau)),
#         down_sampling_module(level2_dau),
#         level3_dau,
#     )
#     # DAU 2
#     level1_dau_2 = dual_attention_unit_block(level1_skff)
#     level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
#     level3_dau_2 = up_sampling_module(
#         up_sampling_module(dual_attention_unit_block(level3_skff))
#     )
#     # SKFF 2
#     skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2)
#     conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
#     return layers.Add()([input_tensor, conv])

# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    level4 = down_sampling_module(level3)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    level4_dau = dual_attention_unit_block(level4)

    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
        up_sampling_module(up_sampling_module(up_sampling_module(level4_dau))),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau),
        level2_dau,
        up_sampling_module(level3_dau),
        up_sampling_module(up_sampling_module(level4_dau)),
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
        up_sampling_module(level4_dau),
    )
    level4_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(down_sampling_module(level1_dau))),
        down_sampling_module(down_sampling_module(level2_dau)),
        down_sampling_module(level3_dau),
        level4_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    level4_dau_2 = up_sampling_module(
        up_sampling_module(
            up_sampling_module(dual_attention_unit_block(level4_skff))
    )
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level3_dau_2, level3_dau_2, level4_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %% [markdown]
# ### MIRNet Model

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=32)

# %% [markdown]
# ## Training
#
# - We train MIRNet using **Charbonnier Loss** as the loss function and **Adam
# Optimizer** with a learning rate of `1e-4`.
# - We use **Peak Signal Noise Ratio** or PSNR as a metric which is an expression for the
# ratio between the maximum possible value (power) of a signal and the power of distorting
# noise that affects the quality of its representation.

# %%
num_epochs = 150
lr = 1e-4

def scheduler(epoch, lr):
  # time-based decay
  decay = 1e-4/50
  return lr * 1/(1 + decay*epoch)

def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=lr)

# callback = keras.callbacks.LearningRateScheduler(scheduler, 1)

# filepath="/content/drive/MyDrive/EE610/checkpoint/model-{epoch:02d}-{loss:.4f}.h5"

# callback2 = keras.callbacks.ModelCheckpoint(
#     filepath=filepath,
#     monitor='val_loss',
#     mode='min',
#     verbose=1,
#     save_best_only=True)

tb_callback = keras.callbacks.TensorBoard(log_dir="./logs/Modofied_MIRNET", histogram_freq=1)

model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

# history = model.fit(
#     train_dataset,
#     validation_data=val_dataset,
#     epochs=150,
#     callbacks=[callback2, callback],
#     )

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        ),
        tb_callback,
    ],
)
# Out:
# C:\Users\Vinit\anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/150
# 100/100 [==============================] - 126s 645ms/step - loss: 0.1997 - peak_signal_noise_ratio: 62.1907 - val_loss: 0.1668 - val_peak_signal_noise_ratio: 63.3128
# Epoch 2/150
# 100/100 [==============================] - 45s 454ms/step - loss: 0.1619 - peak_signal_noise_ratio: 63.7517 - val_loss: 0.1666 - val_peak_signal_noise_ratio: 63.8246
# Epoch 3/150
# 100/100 [==============================] - 47s 474ms/step - loss: 0.1486 - peak_signal_noise_ratio: 64.5328 - val_loss: 0.1623 - val_peak_signal_noise_ratio: 63.9713
# Epoch 4/150
# 100/100 [==============================] - 50s 501ms/step - loss: 0.1425 - peak_signal_noise_ratio: 64.8830 - val_loss: 0.1402 - val_peak_signal_noise_ratio: 65.1511
# Epoch 5/150
# 100/100 [==============================] - 50s 495ms/step - loss: 0.1379 - peak_signal_noise_ratio: 65.2048 - val_loss: 0.1520 - val_peak_signal_noise_ratio: 64.7498
# Epoch 6/150
# 100/100 [==============================] - 49s 491ms/step - loss: 0.1388 - peak_signal_noise_ratio: 65.3541 - val_loss: 0.1523 - val_peak_signal_noise_ratio: 64.9677
# Epoch 7/150
# 100/100 [==============================] - 49s 490ms/step - loss: 0.1332 - peak_signal_noise_ratio: 65.8446 - val_loss: 0.1617 - val_peak_signal_noise_ratio: 64.3043
# Epoch 8/150
# 100/100 [==============================] - 48s 476ms/step - loss: 0.1391 - peak_signal_noise_ratio: 65.6346 - val_loss: 0.1515 - val_peak_signal_noise_ratio: 65.0936
# Epoch 9/150
# 100/100 [==============================] - 46s 463ms/step - loss: 0.1322 - peak_signal_noise_ratio: 65.8423 - val_loss: 0.1508 - val_peak_signal_noise_ratio: 64.8111
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 10/150
# 100/100 [==============================] - 47s 468ms/step - loss: 0.1263 - peak_signal_noise_ratio: 66.1321 - val_loss: 0.1505 - val_peak_signal_noise_ratio: 64.9469
# Epoch 11/150
# 100/100 [==============================] - 48s 479ms/step - loss: 0.1278 - peak_signal_noise_ratio: 66.0932 - val_loss: 0.1533 - val_peak_signal_noise_ratio: 64.8486
# Epoch 12/150
# 100/100 [==============================] - 47s 468ms/step - loss: 0.1273 - peak_signal_noise_ratio: 66.2530 - val_loss: 0.1567 - val_peak_signal_noise_ratio: 64.8734
# Epoch 13/150
# 100/100 [==============================] - 47s 465ms/step - loss: 0.1196 - peak_signal_noise_ratio: 66.7216 - val_loss: 0.1474 - val_peak_signal_noise_ratio: 65.4629
# Epoch 14/150
# 100/100 [==============================] - 46s 462ms/step - loss: 0.1262 - peak_signal_noise_ratio: 66.3429 - val_loss: 0.1589 - val_peak_signal_noise_ratio: 64.7640
# Epoch 15/150
# 100/100 [==============================] - 47s 474ms/step - loss: 0.1225 - peak_signal_noise_ratio: 66.6321 - val_loss: 0.1468 - val_peak_signal_noise_ratio: 65.4001
# Epoch 16/150
# 100/100 [==============================] - 47s 469ms/step - loss: 0.1199 - peak_signal_noise_ratio: 66.8193 - val_loss: 0.1612 - val_peak_signal_noise_ratio: 64.7697
# Epoch 17/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1210 - peak_signal_noise_ratio: 66.8316 - val_loss: 0.1698 - val_peak_signal_noise_ratio: 64.1740
# Epoch 18/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1225 - peak_signal_noise_ratio: 66.6903 - val_loss: 0.1537 - val_peak_signal_noise_ratio: 65.0742
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 19/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1206 - peak_signal_noise_ratio: 66.8467 - val_loss: 0.1412 - val_peak_signal_noise_ratio: 65.7728
# Epoch 20/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1222 - peak_signal_noise_ratio: 66.7960 - val_loss: 0.1464 - val_peak_signal_noise_ratio: 65.1979
# Epoch 21/150
# 100/100 [==============================] - 45s 450ms/step - loss: 0.1228 - peak_signal_noise_ratio: 66.9119 - val_loss: 0.1393 - val_peak_signal_noise_ratio: 65.8311
# Epoch 22/150
# 100/100 [==============================] - 46s 455ms/step - loss: 0.1171 - peak_signal_noise_ratio: 67.1260 - val_loss: 0.1504 - val_peak_signal_noise_ratio: 65.2071
# Epoch 23/150
# 100/100 [==============================] - 46s 464ms/step - loss: 0.1194 - peak_signal_noise_ratio: 67.0441 - val_loss: 0.1296 - val_peak_signal_noise_ratio: 66.3046
# Epoch 24/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1189 - peak_signal_noise_ratio: 67.1955 - val_loss: 0.1383 - val_peak_signal_noise_ratio: 65.7758
# Epoch 25/150
# 100/100 [==============================] - 45s 449ms/step - loss: 0.1143 - peak_signal_noise_ratio: 67.3629 - val_loss: 0.1388 - val_peak_signal_noise_ratio: 65.6006
# Epoch 26/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1161 - peak_signal_noise_ratio: 67.3486 - val_loss: 0.1413 - val_peak_signal_noise_ratio: 65.7797
# Epoch 27/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1208 - peak_signal_noise_ratio: 66.9967 - val_loss: 0.1399 - val_peak_signal_noise_ratio: 65.7070
# Epoch 28/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1191 - peak_signal_noise_ratio: 67.1184 - val_loss: 0.1359 - val_peak_signal_noise_ratio: 66.1068
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 29/150
# 100/100 [==============================] - 47s 473ms/step - loss: 0.1124 - peak_signal_noise_ratio: 67.5658 - val_loss: 0.1260 - val_peak_signal_noise_ratio: 66.6448
# Epoch 30/150
# 100/100 [==============================] - 46s 465ms/step - loss: 0.1155 - peak_signal_noise_ratio: 67.3225 - val_loss: 0.1438 - val_peak_signal_noise_ratio: 65.4747
# Epoch 31/150
# 100/100 [==============================] - 46s 461ms/step - loss: 0.1144 - peak_signal_noise_ratio: 67.2762 - val_loss: 0.1297 - val_peak_signal_noise_ratio: 66.3446
# Epoch 32/150
# 100/100 [==============================] - 47s 465ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.4321 - val_loss: 0.1314 - val_peak_signal_noise_ratio: 66.1610
# Epoch 33/150
# 100/100 [==============================] - 45s 453ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.5396 - val_loss: 0.1207 - val_peak_signal_noise_ratio: 66.8630
# Epoch 34/150
# 100/100 [==============================] - 46s 455ms/step - loss: 0.1156 - peak_signal_noise_ratio: 67.3229 - val_loss: 0.1247 - val_peak_signal_noise_ratio: 66.7338
# Epoch 35/150
# 100/100 [==============================] - 46s 461ms/step - loss: 0.1173 - peak_signal_noise_ratio: 67.1006 - val_loss: 0.1300 - val_peak_signal_noise_ratio: 66.1015
# Epoch 36/150
# 100/100 [==============================] - 47s 469ms/step - loss: 0.1179 - peak_signal_noise_ratio: 67.2474 - val_loss: 0.1261 - val_peak_signal_noise_ratio: 66.4979
# Epoch 37/150
# 100/100 [==============================] - 46s 459ms/step - loss: 0.1150 - peak_signal_noise_ratio: 67.4243 - val_loss: 0.1303 - val_peak_signal_noise_ratio: 66.3306
# Epoch 38/150
# 100/100 [==============================] - 47s 467ms/step - loss: 0.1111 - peak_signal_noise_ratio: 67.6218 - val_loss: 0.1278 - val_peak_signal_noise_ratio: 66.5198
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 39/150
# 100/100 [==============================] - 49s 488ms/step - loss: 0.1172 - peak_signal_noise_ratio: 67.2554 - val_loss: 0.1267 - val_peak_signal_noise_ratio: 66.8491
# Epoch 40/150
# 100/100 [==============================] - 53s 532ms/step - loss: 0.1126 - peak_signal_noise_ratio: 67.7672 - val_loss: 0.1308 - val_peak_signal_noise_ratio: 66.3409
# Epoch 41/150
# 100/100 [==============================] - 53s 531ms/step - loss: 0.1142 - peak_signal_noise_ratio: 67.4430 - val_loss: 0.1231 - val_peak_signal_noise_ratio: 66.7945
# Epoch 42/150
# 100/100 [==============================] - 54s 536ms/step - loss: 0.1137 - peak_signal_noise_ratio: 67.5267 - val_loss: 0.1367 - val_peak_signal_noise_ratio: 65.8936
# Epoch 43/150
# 100/100 [==============================] - 54s 539ms/step - loss: 0.1092 - peak_signal_noise_ratio: 67.8686 - val_loss: 0.1293 - val_peak_signal_noise_ratio: 66.0851
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 44/150
# 100/100 [==============================] - 49s 492ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.4533 - val_loss: 0.1290 - val_peak_signal_noise_ratio: 66.4893
# Epoch 45/150
# 100/100 [==============================] - 48s 477ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.3687 - val_loss: 0.1360 - val_peak_signal_noise_ratio: 66.2673
# Epoch 46/150
# 100/100 [==============================] - 48s 478ms/step - loss: 0.1079 - peak_signal_noise_ratio: 67.9607 - val_loss: 0.1436 - val_peak_signal_noise_ratio: 65.5244
# Epoch 47/150
# 100/100 [==============================] - 48s 476ms/step - loss: 0.1121 - peak_signal_noise_ratio: 67.6233 - val_loss: 0.1226 - val_peak_signal_noise_ratio: 66.6839
# Epoch 48/150
# 100/100 [==============================] - 46s 461ms/step - loss: 0.1111 - peak_signal_noise_ratio: 67.7110 - val_loss: 0.1318 - val_peak_signal_noise_ratio: 66.3505
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 49/150
# 100/100 [==============================] - 46s 461ms/step - loss: 0.1090 - peak_signal_noise_ratio: 67.7380 - val_loss: 0.1213 - val_peak_signal_noise_ratio: 66.9829
# Epoch 50/150
# 100/100 [==============================] - 45s 454ms/step - loss: 0.1133 - peak_signal_noise_ratio: 67.4998 - val_loss: 0.1339 - val_peak_signal_noise_ratio: 66.1942
# Epoch 51/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.8330 - val_loss: 0.1289 - val_peak_signal_noise_ratio: 66.3272
# Epoch 52/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1139 - peak_signal_noise_ratio: 67.4676 - val_loss: 0.1287 - val_peak_signal_noise_ratio: 66.5155
# Epoch 53/150
# 100/100 [==============================] - 45s 452ms/step - loss: 0.1113 - peak_signal_noise_ratio: 67.6086 - val_loss: 0.1364 - val_peak_signal_noise_ratio: 66.0636
# Epoch 54/150
# 100/100 [==============================] - 47s 467ms/step - loss: 0.1079 - peak_signal_noise_ratio: 67.9612 - val_loss: 0.1318 - val_peak_signal_noise_ratio: 66.4069
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 55/150
# 100/100 [==============================] - 47s 469ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.7349 - val_loss: 0.1315 - val_peak_signal_noise_ratio: 66.4960
# Epoch 56/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1144 - peak_signal_noise_ratio: 67.4236 - val_loss: 0.1353 - val_peak_signal_noise_ratio: 65.9672
# Epoch 57/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1065 - peak_signal_noise_ratio: 68.0510 - val_loss: 0.1330 - val_peak_signal_noise_ratio: 66.0706
# Epoch 58/150
# 100/100 [==============================] - 44s 444ms/step - loss: 0.1098 - peak_signal_noise_ratio: 67.6690 - val_loss: 0.1386 - val_peak_signal_noise_ratio: 65.8753
# Epoch 59/150
# 100/100 [==============================] - 47s 472ms/step - loss: 0.1072 - peak_signal_noise_ratio: 67.9403 - val_loss: 0.1341 - val_peak_signal_noise_ratio: 66.0103
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 60/150
# 100/100 [==============================] - 47s 465ms/step - loss: 0.1058 - peak_signal_noise_ratio: 67.9850 - val_loss: 0.1308 - val_peak_signal_noise_ratio: 65.9237
# Epoch 61/150
# 100/100 [==============================] - 48s 475ms/step - loss: 0.1145 - peak_signal_noise_ratio: 67.4609 - val_loss: 0.1279 - val_peak_signal_noise_ratio: 66.6404
# Epoch 62/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1081 - peak_signal_noise_ratio: 67.8092 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 66.1607
# Epoch 63/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1084 - peak_signal_noise_ratio: 67.9568 - val_loss: 0.1350 - val_peak_signal_noise_ratio: 66.0971
# Epoch 64/150
# 100/100 [==============================] - 48s 479ms/step - loss: 0.1118 - peak_signal_noise_ratio: 67.6599 - val_loss: 0.1406 - val_peak_signal_noise_ratio: 65.8978
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 65/150
# 100/100 [==============================] - 45s 454ms/step - loss: 0.1090 - peak_signal_noise_ratio: 67.8941 - val_loss: 0.1305 - val_peak_signal_noise_ratio: 66.3250
# Epoch 66/150
# 100/100 [==============================] - 47s 473ms/step - loss: 0.1092 - peak_signal_noise_ratio: 67.7662 - val_loss: 0.1463 - val_peak_signal_noise_ratio: 65.5226
# Epoch 67/150
# 100/100 [==============================] - 47s 468ms/step - loss: 0.1084 - peak_signal_noise_ratio: 67.7431 - val_loss: 0.1368 - val_peak_signal_noise_ratio: 65.8905
# Epoch 68/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.1130 - peak_signal_noise_ratio: 67.5760 - val_loss: 0.1335 - val_peak_signal_noise_ratio: 65.7753
# Epoch 69/150
# 100/100 [==============================] - 49s 493ms/step - loss: 0.1108 - peak_signal_noise_ratio: 67.8377 - val_loss: 0.1343 - val_peak_signal_noise_ratio: 66.3317
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 70/150
# 100/100 [==============================] - 49s 488ms/step - loss: 0.1114 - peak_signal_noise_ratio: 67.6276 - val_loss: 0.1326 - val_peak_signal_noise_ratio: 66.2965
# Epoch 71/150
# 100/100 [==============================] - 49s 487ms/step - loss: 0.1070 - peak_signal_noise_ratio: 67.9595 - val_loss: 0.1333 - val_peak_signal_noise_ratio: 66.1887
# Epoch 72/150
# 100/100 [==============================] - 47s 471ms/step - loss: 0.1145 - peak_signal_noise_ratio: 67.4211 - val_loss: 0.1346 - val_peak_signal_noise_ratio: 66.0678
# Epoch 73/150
# 100/100 [==============================] - 47s 473ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.3815 - val_loss: 0.1407 - val_peak_signal_noise_ratio: 65.6390
# Epoch 74/150
# 100/100 [==============================] - 50s 500ms/step - loss: 0.1130 - peak_signal_noise_ratio: 67.4919 - val_loss: 0.1330 - val_peak_signal_noise_ratio: 66.2603
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 75/150
# 100/100 [==============================] - 46s 463ms/step - loss: 0.1072 - peak_signal_noise_ratio: 67.9441 - val_loss: 0.1271 - val_peak_signal_noise_ratio: 66.7279
# Epoch 76/150
# 100/100 [==============================] - 46s 461ms/step - loss: 0.1155 - peak_signal_noise_ratio: 67.5857 - val_loss: 0.1338 - val_peak_signal_noise_ratio: 66.1027
# Epoch 77/150
# 100/100 [==============================] - 49s 490ms/step - loss: 0.1133 - peak_signal_noise_ratio: 67.6559 - val_loss: 0.1380 - val_peak_signal_noise_ratio: 65.9680
# Epoch 78/150
# 100/100 [==============================] - 49s 494ms/step - loss: 0.1076 - peak_signal_noise_ratio: 67.9841 - val_loss: 0.1295 - val_peak_signal_noise_ratio: 66.3654
# Epoch 79/150
# 100/100 [==============================] - 51s 509ms/step - loss: 0.1117 - peak_signal_noise_ratio: 67.5550 - val_loss: 0.1264 - val_peak_signal_noise_ratio: 66.6195
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 80/150
# 100/100 [==============================] - 50s 496ms/step - loss: 0.1052 - peak_signal_noise_ratio: 68.0513 - val_loss: 0.1301 - val_peak_signal_noise_ratio: 66.4546
# Epoch 81/150
# 100/100 [==============================] - 51s 514ms/step - loss: 0.1106 - peak_signal_noise_ratio: 67.7736 - val_loss: 0.1338 - val_peak_signal_noise_ratio: 66.3206
# Epoch 82/150
# 100/100 [==============================] - 50s 505ms/step - loss: 0.1106 - peak_signal_noise_ratio: 67.7932 - val_loss: 0.1313 - val_peak_signal_noise_ratio: 66.0830
# Epoch 83/150
# 100/100 [==============================] - 51s 512ms/step - loss: 0.1116 - peak_signal_noise_ratio: 67.7269 - val_loss: 0.1393 - val_peak_signal_noise_ratio: 65.7650
# Epoch 84/150
# 100/100 [==============================] - 49s 490ms/step - loss: 0.1098 - peak_signal_noise_ratio: 67.7695 - val_loss: 0.1318 - val_peak_signal_noise_ratio: 66.1441
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 85/150
# 100/100 [==============================] - 51s 512ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.3261 - val_loss: 0.1375 - val_peak_signal_noise_ratio: 65.9826
# Epoch 86/150
# 100/100 [==============================] - 50s 500ms/step - loss: 0.1069 - peak_signal_noise_ratio: 68.0572 - val_loss: 0.1389 - val_peak_signal_noise_ratio: 65.9596
# Epoch 87/150
# 100/100 [==============================] - 50s 497ms/step - loss: 0.1124 - peak_signal_noise_ratio: 67.6576 - val_loss: 0.1356 - val_peak_signal_noise_ratio: 65.8572
# Epoch 88/150
# 100/100 [==============================] - 50s 496ms/step - loss: 0.1136 - peak_signal_noise_ratio: 67.4477 - val_loss: 0.1325 - val_peak_signal_noise_ratio: 66.3434
# Epoch 89/150
# 100/100 [==============================] - 45s 454ms/step - loss: 0.1110 - peak_signal_noise_ratio: 67.5947 - val_loss: 0.1398 - val_peak_signal_noise_ratio: 65.6864
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 90/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1123 - peak_signal_noise_ratio: 67.5623 - val_loss: 0.1419 - val_peak_signal_noise_ratio: 65.5710
# Epoch 91/150
# 100/100 [==============================] - 47s 471ms/step - loss: 0.1125 - peak_signal_noise_ratio: 67.5468 - val_loss: 0.1359 - val_peak_signal_noise_ratio: 66.1286
# Epoch 92/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1115 - peak_signal_noise_ratio: 67.6335 - val_loss: 0.1364 - val_peak_signal_noise_ratio: 65.8927
# Epoch 93/150
# 100/100 [==============================] - 45s 454ms/step - loss: 0.1100 - peak_signal_noise_ratio: 67.7503 - val_loss: 0.1320 - val_peak_signal_noise_ratio: 66.2750
# Epoch 94/150
# 100/100 [==============================] - 47s 466ms/step - loss: 0.1130 - peak_signal_noise_ratio: 67.4740 - val_loss: 0.1385 - val_peak_signal_noise_ratio: 65.9358
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 95/150
# 100/100 [==============================] - 45s 451ms/step - loss: 0.1070 - peak_signal_noise_ratio: 67.8687 - val_loss: 0.1335 - val_peak_signal_noise_ratio: 66.0768
# Epoch 96/150
# 100/100 [==============================] - 47s 472ms/step - loss: 0.1099 - peak_signal_noise_ratio: 67.8607 - val_loss: 0.1365 - val_peak_signal_noise_ratio: 65.8387
# Epoch 97/150
# 100/100 [==============================] - 47s 474ms/step - loss: 0.1128 - peak_signal_noise_ratio: 67.5838 - val_loss: 0.1316 - val_peak_signal_noise_ratio: 66.6669
# Epoch 98/150
# 100/100 [==============================] - 47s 467ms/step - loss: 0.1053 - peak_signal_noise_ratio: 68.0081 - val_loss: 0.1349 - val_peak_signal_noise_ratio: 66.0541
# Epoch 99/150
# 100/100 [==============================] - 47s 468ms/step - loss: 0.1135 - peak_signal_noise_ratio: 67.6055 - val_loss: 0.1262 - val_peak_signal_noise_ratio: 66.5201
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 100/150
# 100/100 [==============================] - 47s 468ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.7685 - val_loss: 0.1383 - val_peak_signal_noise_ratio: 65.6864
# Epoch 101/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.9009 - val_loss: 0.1413 - val_peak_signal_noise_ratio: 65.6021
# Epoch 102/150
# 100/100 [==============================] - 46s 465ms/step - loss: 0.1081 - peak_signal_noise_ratio: 67.7722 - val_loss: 0.1305 - val_peak_signal_noise_ratio: 66.5052
# Epoch 103/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.7484 - val_loss: 0.1332 - val_peak_signal_noise_ratio: 66.2438
# Epoch 104/150
# 100/100 [==============================] - 46s 455ms/step - loss: 0.1080 - peak_signal_noise_ratio: 67.9797 - val_loss: 0.1383 - val_peak_signal_noise_ratio: 65.7907
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 105/150
# 100/100 [==============================] - 46s 462ms/step - loss: 0.1096 - peak_signal_noise_ratio: 67.8682 - val_loss: 0.1280 - val_peak_signal_noise_ratio: 66.5118
# Epoch 106/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1124 - peak_signal_noise_ratio: 67.6219 - val_loss: 0.1207 - val_peak_signal_noise_ratio: 66.9256
# Epoch 107/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1097 - peak_signal_noise_ratio: 67.9620 - val_loss: 0.1226 - val_peak_signal_noise_ratio: 66.7572
# Epoch 108/150
# 100/100 [==============================] - 45s 445ms/step - loss: 0.1111 - peak_signal_noise_ratio: 67.7270 - val_loss: 0.1359 - val_peak_signal_noise_ratio: 66.0742
# Epoch 109/150
# 100/100 [==============================] - 45s 452ms/step - loss: 0.1078 - peak_signal_noise_ratio: 67.9294 - val_loss: 0.1434 - val_peak_signal_noise_ratio: 65.5053
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# Epoch 110/150
# 100/100 [==============================] - 45s 450ms/step - loss: 0.1099 - peak_signal_noise_ratio: 67.7430 - val_loss: 0.1333 - val_peak_signal_noise_ratio: 65.9485
# Epoch 111/150
# 100/100 [==============================] - 47s 466ms/step - loss: 0.1092 - peak_signal_noise_ratio: 67.8541 - val_loss: 0.1297 - val_peak_signal_noise_ratio: 66.7181
# Epoch 112/150
# 100/100 [==============================] - 47s 473ms/step - loss: 0.1128 - peak_signal_noise_ratio: 67.6066 - val_loss: 0.1244 - val_peak_signal_noise_ratio: 66.6975
# Epoch 113/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1069 - peak_signal_noise_ratio: 67.8701 - val_loss: 0.1337 - val_peak_signal_noise_ratio: 66.0158
# Epoch 114/150
# 100/100 [==============================] - 47s 466ms/step - loss: 0.1097 - peak_signal_noise_ratio: 67.9108 - val_loss: 0.1367 - val_peak_signal_noise_ratio: 65.9599
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 1.9073485846288207e-10.
# Epoch 115/150
# 100/100 [==============================] - 46s 463ms/step - loss: 0.1126 - peak_signal_noise_ratio: 67.7615 - val_loss: 0.1327 - val_peak_signal_noise_ratio: 66.1379
# Epoch 116/150
# 100/100 [==============================] - 45s 452ms/step - loss: 0.1097 - peak_signal_noise_ratio: 67.8322 - val_loss: 0.1335 - val_peak_signal_noise_ratio: 66.3502
# Epoch 117/150
# 100/100 [==============================] - 46s 464ms/step - loss: 0.1107 - peak_signal_noise_ratio: 67.6898 - val_loss: 0.1338 - val_peak_signal_noise_ratio: 66.1511
# Epoch 118/150
# 100/100 [==============================] - 45s 453ms/step - loss: 0.1073 - peak_signal_noise_ratio: 67.7641 - val_loss: 0.1419 - val_peak_signal_noise_ratio: 65.5939
# Epoch 119/150
# 100/100 [==============================] - 47s 467ms/step - loss: 0.1071 - peak_signal_noise_ratio: 67.9341 - val_loss: 0.1364 - val_peak_signal_noise_ratio: 66.2325
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# Epoch 120/150
# 100/100 [==============================] - 47s 472ms/step - loss: 0.1106 - peak_signal_noise_ratio: 67.7581 - val_loss: 0.1357 - val_peak_signal_noise_ratio: 66.0323
# Epoch 121/150
# 100/100 [==============================] - 46s 459ms/step - loss: 0.1069 - peak_signal_noise_ratio: 67.9905 - val_loss: 0.1392 - val_peak_signal_noise_ratio: 65.8745
# Epoch 122/150
# 100/100 [==============================] - 47s 466ms/step - loss: 0.1099 - peak_signal_noise_ratio: 67.6999 - val_loss: 0.1385 - val_peak_signal_noise_ratio: 65.8470
# Epoch 123/150
# 100/100 [==============================] - 47s 470ms/step - loss: 0.1108 - peak_signal_noise_ratio: 67.5577 - val_loss: 0.1360 - val_peak_signal_noise_ratio: 66.1542
# Epoch 124/150
# 100/100 [==============================] - 47s 466ms/step - loss: 0.1077 - peak_signal_noise_ratio: 67.9875 - val_loss: 0.1393 - val_peak_signal_noise_ratio: 65.7310
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 4.768371461572052e-11.
# Epoch 125/150
# 100/100 [==============================] - 46s 463ms/step - loss: 0.1086 - peak_signal_noise_ratio: 67.9678 - val_loss: 0.1326 - val_peak_signal_noise_ratio: 66.0956
# Epoch 126/150
# 100/100 [==============================] - 46s 462ms/step - loss: 0.1123 - peak_signal_noise_ratio: 67.5870 - val_loss: 0.1395 - val_peak_signal_noise_ratio: 65.7417
# Epoch 127/150
# 100/100 [==============================] - 46s 462ms/step - loss: 0.1093 - peak_signal_noise_ratio: 67.7985 - val_loss: 0.1370 - val_peak_signal_noise_ratio: 66.1067
# Epoch 128/150
# 100/100 [==============================] - 45s 455ms/step - loss: 0.1102 - peak_signal_noise_ratio: 67.8053 - val_loss: 0.1349 - val_peak_signal_noise_ratio: 65.9251
# Epoch 129/150
# 100/100 [==============================] - 46s 464ms/step - loss: 0.1127 - peak_signal_noise_ratio: 67.5046 - val_loss: 0.1336 - val_peak_signal_noise_ratio: 66.1118
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# Epoch 130/150
# 100/100 [==============================] - 46s 463ms/step - loss: 0.1085 - peak_signal_noise_ratio: 67.8164 - val_loss: 0.1343 - val_peak_signal_noise_ratio: 65.9947
# Epoch 131/150
# 100/100 [==============================] - 46s 464ms/step - loss: 0.1099 - peak_signal_noise_ratio: 67.8474 - val_loss: 0.1346 - val_peak_signal_noise_ratio: 65.9129
# Epoch 132/150
# 100/100 [==============================] - 46s 465ms/step - loss: 0.1093 - peak_signal_noise_ratio: 67.7648 - val_loss: 0.1418 - val_peak_signal_noise_ratio: 65.8494
# Epoch 133/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1116 - peak_signal_noise_ratio: 67.5873 - val_loss: 0.1396 - val_peak_signal_noise_ratio: 65.7945
# Epoch 134/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.5708 - val_loss: 0.1307 - val_peak_signal_noise_ratio: 66.2031
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 1.192092865393013e-11.
# Epoch 135/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1061 - peak_signal_noise_ratio: 68.1693 - val_loss: 0.1342 - val_peak_signal_noise_ratio: 66.2459
# Epoch 136/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.6389 - val_loss: 0.1280 - val_peak_signal_noise_ratio: 66.3584
# Epoch 137/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1094 - peak_signal_noise_ratio: 67.7884 - val_loss: 0.1356 - val_peak_signal_noise_ratio: 65.9127
# Epoch 138/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1087 - peak_signal_noise_ratio: 67.7668 - val_loss: 0.1365 - val_peak_signal_noise_ratio: 66.0803
# Epoch 139/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1114 - peak_signal_noise_ratio: 67.7501 - val_loss: 0.1339 - val_peak_signal_noise_ratio: 65.9043
#
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 5.960464326965065e-12.
# Epoch 140/150
# 100/100 [==============================] - 46s 462ms/step - loss: 0.1081 - peak_signal_noise_ratio: 67.8793 - val_loss: 0.1310 - val_peak_signal_noise_ratio: 66.2941
# Epoch 141/150
# 100/100 [==============================] - 46s 460ms/step - loss: 0.1066 - peak_signal_noise_ratio: 67.8895 - val_loss: 0.1356 - val_peak_signal_noise_ratio: 65.9329
# Epoch 142/150
# 100/100 [==============================] - 47s 463ms/step - loss: 0.1101 - peak_signal_noise_ratio: 67.7473 - val_loss: 0.1306 - val_peak_signal_noise_ratio: 66.2582
# Epoch 143/150
# 100/100 [==============================] - 46s 457ms/step - loss: 0.1110 - peak_signal_noise_ratio: 67.6082 - val_loss: 0.1408 - val_peak_signal_noise_ratio: 65.7088
# Epoch 144/150
# 100/100 [==============================] - 46s 456ms/step - loss: 0.1078 - peak_signal_noise_ratio: 67.8896 - val_loss: 0.1290 - val_peak_signal_noise_ratio: 66.6016
#
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 2.9802321634825324e-12.
# Epoch 145/150
# 100/100 [==============================] - 48s 475ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.7939 - val_loss: 0.1354 - val_peak_signal_noise_ratio: 66.1268
# Epoch 146/150
# 100/100 [==============================] - 46s 458ms/step - loss: 0.1078 - peak_signal_noise_ratio: 67.7323 - val_loss: 0.1279 - val_peak_signal_noise_ratio: 66.4368
# Epoch 147/150
# 100/100 [==============================] - 46s 465ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.8439 - val_loss: 0.1329 - val_peak_signal_noise_ratio: 66.1356
# Epoch 148/150
# 100/100 [==============================] - 47s 465ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.6806 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 65.9939
# Epoch 149/150
# 100/100 [==============================] - 50s 504ms/step - loss: 0.1082 - peak_signal_noise_ratio: 67.9336 - val_loss: 0.1358 - val_peak_signal_noise_ratio: 66.1001
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 1.4901160817412662e-12.
# Epoch 150/150
# 100/100 [==============================] - 49s 489ms/step - loss: 0.1087 - peak_signal_noise_ratio: 67.7935 - val_loss: 0.1334 - val_peak_signal_noise_ratio: 65.9062

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/loss_over_epochs"+str(num_epochs)+"_"+"Modified_MIRNET.png")
plt.show()


plt.plot(history.history["peak_signal_noise_ratio"], label="train_psnr")
plt.plot(history.history["val_peak_signal_noise_ratio"], label="val_psnr")
plt.xlabel("Epochs")
plt.ylabel("PSNR")
plt.title("Train and Validation PSNR Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.savefig("Results/psnr_over_epochs"+str(num_epochs)+"_"+"Modified_MIRNET.png")
plt.show()

# %% [markdown]
# ## Inference

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %% [markdown]
# ### Inference on Test Images
#
# We compare the test images from LOLDataset enhanced by MIRNet with images
# enhanced via the `PIL.ImageOps.autocontrast()` function.

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )

# %%
model.save("models/mirnet_model_Modified_MIRNET_epochs"+"_"+str(num_epochs)+"_"+str(MAX_TRAIN_IMAGES)+".h5")
